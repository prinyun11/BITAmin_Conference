# %%
import pandas as pd
import numpy as np
import re
from hanspell import spell_checker
from konlpy.tag import Mecab
import konlpy

# %%
trade_df = pd.read_excel('data/crawling/유통_무역_운송.xls')
edu_df = pd.read_excel('data/crawling/교육업.xls')
cons_df = pd.read_excel('data/crawling/건설업.xls')

# %%
trade_df.drop('Unnamed: 0', axis = 1, inplace = True)
edu_df.drop('Unnamed: 0', axis = 1, inplace = True)
cons_df.drop('Unnamed: 0', axis = 1, inplace = True)

# %%
trade_df.set_index('회사', inplace = True)
edu_df.set_index('회사', inplace = True)
cons_df.set_index('회사', inplace = True)

# %%
trade_df.drop_duplicates(['요약','장점','단점','경영진에게 바라는 점'], inplace = True)
edu_df.drop_duplicates(['요약','장점','단점','경영진에게 바라는 점'], inplace = True)
cons_df.drop_duplicates(['요약','장점','단점','경영진에게 바라는 점'], inplace = True)

# %%
cons_df.isnull().sum()
# Out:
# 날짜             0
# 직무             0
# 요약             0
# 장점             0
# 단점             0
# 경영진에게 바라는 점    0
# dtype: int64

# %%
# null값 제거
index = cons_df[cons_df['경영진에게 바라는 점'].isnull()].index
cons_df.drop(index, inplace = True)

# %%
# 영어와 한글만 남기는 함수 정의
def clean_text(df):
    for col in df.columns[2:]:
        df[col] = df[col].str.replace("[^가-힇]", " ")

# %%
# py-hanspell을 이용한 맞춤법 검사 함수 정의
def spelling(df):
    # [요약]부터 [경영진에게 바라는 점]까지
    for col in df.columns[2:]:
        for j in range(df.shape[0]):
            try:
                if len(df[col][j])>500:
                    idx=df[col][j].rfind(' ',0,500)
                    df[col][j]=spell_checker.check(df[col][j][:idx]).checked+spell_checker.check(df[col][j][idx:]).checked
                # 고칠 게 있으면 고치고 기존 데이터 대체
                else:
                    result_train = spell_checker.check(df[col][j])
                    df[col][j] = result_train.checked
            except:
                # 없으면 pass
                pass

# %%
clean_text(edu_df)

# %%
spelling(trade_df)

# %%
cons_df.to_excel(excel_writer = '건설업_전처리.xlsx')

# %%
# mecab 토큰화 및 불용어 처리
mecab = Mecab()
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize

korean_stopwords_path='./stopword_수정.txt'

# 텍스트 파일 오픈
with open(korean_stopwords_path,encoding='utf-8') as f:
    stopwords=f.readlines()
stopwords=[x.strip() for x in stopwords]

# %%
def tokenize(df):
    for col in df.columns[2:]:
        df[col+'토큰화'] = df[col].apply(mecab.morphs)
        df[col+'토큰화'] = df[col+'토큰화'].apply(lambda x: [item for item in x if item not in stopwords])

# %%
tokenize(cons_df)

# %%
cons_df.head()
# Out:
#                 날짜         직무  \
# 회사
# 한국토지주택공사  2021. 03   서비스/고객지원
# 한국토지주택공사  2021. 03      인사/총무
# 한국토지주택공사  2021. 03      인사/총무
# 한국토지주택공사  2021. 03  경영/기획/컨설팅
# 한국토지주택공사  2021. 03  경영/기획/컨설팅
#
#                                                          요약  \
# 회사
# 한국토지주택공사                    적당한 연봉과 자기 삶을 지킬 수 있는 균형 잡  회사
# 한국토지주택공사                              딱 일하려고 모인 사람들의 집단이었다
# 한국토지주택공사   안정적인 듯 안정적이지 않은 조직  기존     대 직원들과 신입   대 직원들의...
# 한국토지주택공사                  정말 좋은 회사였습니다 동료들도 너무 좋고 복지도 좋았어요
# 한국토지주택공사                   가족 같은 분위기로 안정적으로 오래 다닐 수 있는 회사
#
#                                                          장점  \
# 회사
# 한국토지주택공사               공기업의 특성상 안정적인고 업무 강도도 적당한 또한 사람들이 착함
# 한국토지주택공사         휴가에 대한 게 눈치 보지 않고 자유로워서 좋았다 카페  사내식당 등이 좋다
# 한국토지주택공사  직원들을 위한 복지제도가 잘 되어있음  토목건축 전공자들에게는 전공을 살릴 수 있는...
# 한국토지주택공사                 연차 눈치 안 보고 쓰기 가능  분위기 자유로움  동료들 좋음
# 한국토지주택공사    안정적이다  돈 꼬박꼬박 준다  가족적이다  가늘고 길게 다니고 싶은 사람에게 좋다
#
#                                                          단점  \
# 회사
# 한국토지주택공사                  공기업의 특성상 지방 또는 외곽 쪽에서 근무하는 경우가 많음
# 한국토지주택공사               승진에 대한 경쟁을 하려는 게 보인다  윗사람 아랫사람 눈치 보임
# 한국토지주택공사  순환근무로 인해서 짧으면  년 길면  년 사이에 계속 부서를 옮겨야 한다  부서 이...
# 한국토지주택공사              발령 날 때 전국구다 보니 가족끼리 떨어져 사는 경우가 많이 보였음
# 한국토지주택공사                      진취적인 성향의 사람이라면 잘 맞지 않을 수 있습니다
#
#                                                 경영진에게 바라는 점  \
# 회사
# 한국토지주택공사                  외근의 경우 억조 여자와 남자 모두에게 공평하면 좋겠습니다
# 한국토지주택공사                       터지는 문제들을 잘 해결하길  앞으로 더 반성하길
# 한국토지주택공사  기본적인 마인드가 의전을 중요시 여기는 등 매우 수직적임  시각을 좀 더 다양하게 ...
# 한국토지주택공사           신입사원 많이 뽑아주시면 감사하겠습니다  인턴이었지만 정규직 입사 원해요
# 한국토지주택공사              공기업이지만 성과에 따른 차등이 있으면 좋겠습니다  의욕이 달어져요
#
#                                                       요약토큰화  \
# 회사
# 한국토지주택공사                     [적당, 연봉, 자기, 삶, 지킬, 균형, 잡, 회사]
# 한국토지주택공사                             [려고, 모인, 사람, 집단, 었, 다]
# 한국토지주택공사  [안정, 적, 인, 듯, 안정, 적, 조직, 기존, 대, 직원, 신입, 대, 직원,...
# 한국토지주택공사         [정말, 좋, 회사, 였, 동료, 너무, 좋, 고, 복지, 좋, 았, 어요]
# 한국토지주택공사                       [가족, 분위기, 안정, 적, 오래, 다닐, 회사]
#
#                                                       장점토큰화  \
# 회사
# 한국토지주택공사      [공기업, 특성, 상, 안정, 적, 인, 고, 업무, 강도, 적당, 사람, 착함]
# 한국토지주택공사  [휴가, 대한, 게, 눈치, 고, 자유, 로워서, 좋, 았, 다, 카페, 사내, 식...
# 한국토지주택공사       [직원, 위한, 복지, 제도, 음, 토목건축, 전공, 전공, 살릴, 좋, 직장]
# 한국토지주택공사    [연차, 눈치, 안, 고, 쓰, 기, 가능, 분위기, 자유, 로움, 동료, 좋, 음]
# 한국토지주택공사  [안정, 적, 다, 돈, 꼬박꼬박, 준다, 가족, 적, 다, 가늘, 고, 길, 게,...
#
#                                                       단점토큰화  \
# 회사
# 한국토지주택공사          [공기업, 특성, 상, 지방, 또는, 외곽, 쪽, 근무, 경우, 많, 음]
# 한국토지주택공사        [승진, 대한, 경쟁, 려는, 게, 보인다, 윗사람, 아랫사람, 눈치, 보임]
# 한국토지주택공사  [순환, 근무, 인해서, 짧, 으면, 길, 면, 사이, 계속, 부서, 옮겨야, 한다...
# 한국토지주택공사  [발령, 날, 전국구, 다, 니, 가족, 끼리, 떨어져, 사, 경우, 많이, 보였, 음]
# 한국토지주택공사                          [진취, 적, 인, 성향, 사람, 라면, 맞]
#
#                                              경영진에게 바라는 점토큰화
# 회사
# 한국토지주택공사              [외근, 경우, 억조, 여자, 남자, 모두, 공평, 면, 좋, 겠]
# 한국토지주택공사                       [터지, 문제, 해결, 길, 앞, 더, 반성, 길]
# 한국토지주택공사  [기본, 적, 인, 마인드, 의전, 중요시, 매우, 수직, 적, 임, 더, 다양, ...
# 한국토지주택공사  [신입, 사원, 많이, 뽑, 시, 면, 감사, 겠, 인턴, 었, 정규직, 입사, 원해요]
# 한국토지주택공사              [공기업, 성과, 따른, 차등, 으면, 좋, 겠, 욕, 달, 져요]

# %%
trade_df.to_excel(excel_writer = '유통_무역_운송_토큰화.xlsx')
edu_df.to_excel(excel_writer = '교육업_토큰화.xlsx')
cons_df.to_excel(excel_writer = '건설업_토큰화.xlsx')

# %%
from collections import Counter

# %%
# 코퍼스 생성
edu_corpus = []

for col in edu_df.columns[7:]:
    for i in range(edu_df.shape[0]):
        edu_corpus.append(edu_df[col][i])

# %%
edu_corpus
# Out:
# [['대', '어려서', '분위기', '좋', '음', '상사', '젊', '어서', '소통', '그나마', '통하', '편'],
#  ['어학원',
#   '위',
#   '자부심',
#   '느낄',
#   '음',
#   '다양',
#   '관리법',
#   '콘텐츠',
#   '제작',
#   '능력',
#   '기를',
#   '음',
#   '교육',
#   '업계',
#   '연봉',
#   '괜찮',
#   '편',
#   '해',
#   '커스',
#   '라고',
#   '면',
#   '대',
#   '다',
#   '알',
#   '고',
#   '다',
#   '욕',
#   '그리',
#   '먹',
#   '는지',
#   '모르',
#   '겠',
#   '회사',
#   '팀',
#   '빨리',
#   '려면',
#   '정시',
#   '퇴근',
#   '많이',
#   '한다',
#   '야근',
#   '날',
#   '정해져',
#   '긴',
#   '평일',
#   '휴무',
#   '대체',
#   '해',
#   '줘서',
#   '나름',
#   '합리',
#   '적',
#   '라',
#   '느낀다',
#   '마케팅',
#   '전반',
#   '적',
#   '인',
#   '배울',
#   '곳',
#   '팀',
#   '만나',
#   '면',
#   '정시',
#   '퇴근',
#   '가능',
#   '고',
#   '능력',
#   '인정받',
#   '으면서',
#   '다닐',
#   '다'],
#  ['역량',
#   '빠른',
#   '진급',
#   '가능',
#   '며',
#   '마케팅',
#   '업무',
#   '빠르',
#   '게',
#   '체계',
#   '적',
#   '배울',
#   '곳',
#   '회',
#   '대',
#   '규모',
#   '전',
#   '직원',
#   '기업',
#   '행사',
#   '워크숍',
#   '송년회',
#   '음'],
#  ['역량',
#   '승진',
#   '빠르',
#   '며',
#   '다양',
#   '기업',
#   '문화',
#   '행사',
#   '다',
#   '수평',
#   '적',
#   '인',
#   '업무',
#   '분위기',
#   '자신',
#   '아이디어',
#   '눈치',
#   '고',
#   '제안'],
#  ['젊',
#   '상사',
#   '수평',
#   '적',
#   '인',
#   '분위기',
#   '상명하복',
#   '보다',
#   '회의',
#   '중심',
#   '업무',
#   '프로세스',
#   '진행',
#   '됨',
#   '사람',
#   '한테',
#   '스트레스',
#   '받',
#   '크',
#   '게',
#   '다는',
#   '장점'],
#  ['다양', '프로젝트', '많이', '할', '점', '동료', '분', '다', '젊', '편', '라', '학교', '분위기'],
#  ['연차',
#   '사용',
#   '자유',
#   '롭',
#   '많',
#   '아서',
#   '쓸',
#   '음',
#   '글쎄',
#   '장점',
#   '보다',
#   '단점',
#   '많',
#   '음'],
#  ['연차',
#   '눈치',
#   '안',
#   '봄',
#   '복지',
#   '신경',
#   '쓰',
#   '려는',
#   '중',
#   '강남역',
#   '가까워',
#   '서',
#   '출퇴근',
#   '용'],
#  ['어요',
#   '유일',
#   '장점',
#   '자율',
#   '성',
#   '정도',
#   '어서',
#   '근무',
#   '중',
#   '나가',
#   '서',
#   '산책',
#   '고',
#   '돌아올',
#   '다는',
#   '자그마',
#   '장점',
#   '었',
#   '는데',
#   '최근',
#   '부재',
#   '관리',
#   '프로그램',
#   '생겨서',
#   '분만',
#   '마우스',
#   '안',
#   '움직이',
#   '면',
#   '자리',
#   '비움',
#   '인지',
#   '사유',
#   '써야',
#   '합니다',
#   '자율',
#   '성',
#   '빼앗겼',
#   '으니',
#   '이제',
#   '장점',
#   '정말',
#   '하나'],
#  ['비교',
#   '적',
#   '수평',
#   '적',
#   '인',
#   '사무실',
#   '분위기',
#   '어학원',
#   '수업',
#   '지원',
#   '야근',
#   '때문',
#   '긴',
#   '함',
#   '팀',
#   '맞',
#   '으면',
#   '돈',
#   '욕심',
#   '없이',
#   '재밌',
#   '게',
#   '다닐',
#   '음'],
#  ['빨리', '배울', '너무', '많', '아서', '근속', '기간', '길', '젊', '직원', '많', '친해질'],
#  ['연차',
#   '눈치',
#   '없이',
#   '쓸',
#   '음',
#   '떡값',
#   '음',
#   '커리어',
#   '쌓',
#   '기',
#   '좋',
#   '음',
#   '좋',
#   '회사',
#   '위치'],
#  ['스토리',
#   '기',
#   '편하',
#   '고',
#   '사람',
#   '젊',
#   '축',
#   '속해',
#   '좋',
#   '사람',
#   '많',
#   '강남역',
#   '역세',
#   '권',
#   '근처',
#   '회사',
#   '입니다',
#   '근속',
#   '연수',
#   '짧',
#   '아서',
#   '싫',
#   '사람',
#   '금방',
#   '안',
#   '볼',
#   '어요'],
#  ['나름',
#   '회사',
#   '타이틀',
#   '달',
#   '고',
#   '업무',
#   '기초',
#   '경력',
#   '쌓',
#   '기',
#   '좋',
#   '음',
#   '특',
#   '참고서',
#   '관련',
#   '된',
#   '부서',
#   '라면',
#   '꽤',
#   '프로페셔널',
#   '을까',
#   '생각',
#   '됨',
#   '영상',
#   '식',
#   '경우',
#   '부서',
#   '내',
#   '소속',
#   '영상팀',
#   '소속',
#   '구별',
#   '데',
#   '미',
#   '경력',
#   '쌓',
#   '고',
#   '싶',
#   '다면',
#   '영상팀',
#   '쪽',
#   '더',
#   '좋',
#   '다고',
#   '생각',
#   '함'],
#  ['중요', '프로젝트', '투입', '됨', '업무', '책임감', '기를', '다'],
#  ['젊',
#   '사람',
#   '많',
#   '아서',
#   '분위',
#   '자유',
#   '롭',
#   '고',
#   '밝',
#   '다',
#   '옷',
#   '이나',
#   '머리',
#   '다',
#   '자유',
#   '롭',
#   '고',
#   '분위기',
#   '좋',
#   '았',
#   '다',
#   '팀워크',
#   '좋',
#   '보였',
#   '다'],
#  ['음', '장점', '연차', '쓸', '네임', '밸류'],
#  ['인터넷',
#   '강의',
#   '수강',
#   '가능',
#   '함',
#   '휴양지',
#   '할인',
#   '금액',
#   '예약',
#   '가능',
#   '아침',
#   '먹',
#   '으라고',
#   '우유',
#   '랑',
#   '빵',
#   '줌',
#   '주변',
#   '명함',
#   '면',
#   '할인',
#   '곳',
#   '많',
#   '음'],
#  ['젊음', '팀원', '대부분', '착하', '다', '인트라넷', '다'],
#  ['장점', '달', '번', '자사', '강의', '신청', '해서', '다'],
#  ['해',
#   '커스',
#   '라는',
#   '자부심',
#   '부케',
#   '부',
#   '인',
#   '듯',
#   '건물',
#   '넓',
#   '음',
#   '해',
#   '커스',
#   '지원',
#   '해',
#   '교육',
#   '음'],
#  ['강남역',
#   '라',
#   '약속',
#   '잡',
#   '기',
#   '편함',
#   '사무실',
#   '전자레인지',
#   '랑',
#   '냉장고',
#   '음',
#   '직원',
#   '대',
#   '중',
#   '후반',
#   '라',
#   '편하',
#   '고',
#   '수평',
#   '적',
#   '임',
#   '초고속',
#   '승진',
#   '가능'],
#  ['젊', '나이', '대', '팀원', '어서', '공감대', '형성', '기', '좋', '다', '이름', '알아주', '기업'],
#  ['팀', '특성', '상', '야근', '별로', '음', '워', '라벨', '가능', '평소', '음'],
#  ['강남역', '앞', '시', '넘', '게', '야근', '면', '택시', '비', '지원', '해', '줌'],
#  ['퇴사',
#   '사람',
#   '많',
#   '아서',
#   '직원',
#   '교체',
#   '주기',
#   '빠르',
#   '다',
#   '니',
#   '빨리',
#   '승진',
#   '할',
#   '음',
#   '회사',
#   '리조트',
#   '쓸',
#   '음'],
#  ['개월', '지나', '면', '팀', '최고참', '될', '다는', '거', '여하튼', '승진', '빨리', '할', '음'],
#  ['교육',
#   '회사',
#   '다',
#   '니',
#   '여러',
#   '강의',
#   '다',
#   '시간',
#   '음',
#   '젊',
#   '사람',
#   '많',
#   '음',
#   '퇴사',
#   '많',
#   '아서',
#   '승진',
#   '빠름'],
#  ['좋아하',
#   '워커',
#   '홀릭',
#   '라면',
#   '추천',
#   '한다',
#   '야근',
#   '많이',
#   '함',
#   '함',
#   '평가',
#   '문화',
#   '다',
#   '동기',
#   '매우',
#   '끈끈',
#   '정',
#   '쌓',
#   '다'],
#  ['직원',
#   '젊',
#   '어서',
#   '소통',
#   '됨',
#   '사원',
#   '급',
#   '의견',
#   '제시',
#   '해도',
#   '줌',
#   '능동',
#   '적',
#   '인',
#   '업무',
#   '가능'],
#  ['개발자',
#   '퍼블리셔',
#   '로서',
#   '맘',
#   '편',
#   '다니',
#   '기',
#   '엔',
#   '좋',
#   '음',
#   '영어',
#   '수업',
#   '무료',
#   '음'],
#  ['장점',
#   '성',
#   '능력',
#   '중심',
#   '평가',
#   '기',
#   '때문',
#   '능력',
#   '출중',
#   '다면',
#   '빠른',
#   '진급',
#   '가능',
#   '다는',
#   '점'],
#  ['장점', '직원', '다', '어려서', '복장', '자유', '롭', '다는', '거', '정도', '인', '아요'],
#  ['음',
#   '굳이',
#   '해',
#   '자면',
#   '식빵',
#   '냉장고',
#   '다',
#   '화장실',
#   '깨끗',
#   '다',
#   '점심',
#   '시간',
#   '칼',
#   '다',
#   '위치',
#   '강남',
#   '다',
#   '주변',
#   '먹',
#   '게',
#   '많',
#   '다',
#   '직원',
#   '나이',
#   '대',
#   '젊',
#   '다',
#   '정도'],
#  ['많', '해', '볼', '다는', '장점', '비슷', '또래', '많', '직장', '동료', '관계', '좋', '음'],
#  ['연차', '자유', '롭', '게', '쓸', '음', '네임', '밸류', '편리', '위치', '젊', '연령', '대'],
#  ['많',
#   '아서',
#   '연차',
#   '비해',
#   '경험',
#   '할',
#   '많',
#   '았',
#   '음',
#   '강남',
#   '으면',
#   '신기',
#   '게',
#   '동료',
#   '다',
#   '좋',
#   '음'],
#  ['사회',
#   '초년생',
#   '많이',
#   '입사',
#   '해서',
#   '연령',
#   '대',
#   '젊',
#   '고',
#   '야근',
#   '많',
#   '아서',
#   '야근',
#   '식대',
#   '지급'],
#  ['대', '젊', '들어도', '으쌰', '으쌰', '며', '게', '고', '빡세', '게', '만큼', '얻', '많', '음'],
#  ['연차', '눈치', '안', '고', '사용', '가능', '개인', '업무', '주도', '적', '이끌', '나갈', '음'],
#  ['많', '커리어', '욕심', '사람', '좋', '음', '많', '커리어', '욕심', '사람', '좋', '음'],
#  ['연령', '대가', '비교', '적', '젊', '어서', '팀원', '끼리', '의사소통', '음'],
#  ['업무',
#   '체계',
#   '명확',
#   '해서',
#   '빠른',
#   '업무',
#   '처리',
#   '가능',
#   '함',
#   '온라인',
#   '마케팅',
#   '배울',
#   '음',
#   '다양',
#   '사이트',
#   '운영',
#   '경험',
#   '할',
#   '음'],
#  ['신입',
#   '들어가',
#   '서',
#   '배우',
#   '면',
#   '회사',
#   '던',
#   '적',
#   '응',
#   '함',
#   '매뉴얼',
#   '체계',
#   '확실',
#   '해서',
#   '바닥',
#   '배울',
#   '음',
#   '외',
#   '음'],
#  ['연차',
#   '자유',
#   '롭',
#   '게',
#   '사용',
#   '할',
#   '음',
#   '회사',
#   '인근',
#   '인프라',
#   '많',
#   '아서',
#   '이용',
#   '용',
#   '고',
#   '나름',
#   '복지',
#   '제도',
#   '개설',
#   '다'],
#  ['장점',
#   '많',
#   '사람',
#   '리뷰',
#   '적혀',
#   '토스트',
#   '가장',
#   '큰',
#   '장점',
#   '아닌가',
#   '싶',
#   '다',
#   '정리',
#   '안',
#   '된',
#   '토스',
#   '트기',
#   '근처',
#   '너저분',
#   '게',
#   '빵',
#   '가루',
#   '다',
#   '정말',
#   '많이',
#   '할',
#   '다',
#   '자신',
#   '멀티태스킹',
#   '능력',
#   '확인',
#   '할'],
#  ['젊',
#   '사람',
#   '많',
#   '기업',
#   '어서',
#   '뜻',
#   '만',
#   '맞',
#   '으면',
#   '업무',
#   '수평',
#   '적',
#   '업무',
#   '할',
#   '다'],
#  ['직원',
#   '젊',
#   '어서',
#   '소위',
#   '꼰대',
#   '아재',
#   '다',
#   '회식',
#   '자주',
#   '어서',
#   '회식',
#   '땜',
#   '고',
#   '그런',
#   '면',
#   '음'],
#  ['진급',
#   '빨리',
#   '다',
#   '실제로',
#   '대가',
#   '았',
#   '는데',
#   '팀장',
#   '자리',
#   '사람',
#   '적',
#   '게',
#   '보인',
#   '걸로',
#   '기억',
#   '한다',
#   '단점',
#   '될',
#   '다',
#   '생각',
#   '노련',
#   '함',
#   '팀장',
#   '이미지',
#   '아닌',
#   '팀장',
#   '다'],
#  ['특정', '인', '강', '음', '주말', '평일', '경계', '질', '음'],
#  ['대',
#   '어림',
#   '유연',
#   '조직',
#   '문화',
#   '여름휴가',
#   '제공',
#   '휴양소',
#   '전용',
#   '객실',
#   '제공',
#   '진급',
#   '빠르',
#   '다'],
#  ['강남역',
#   '이랑',
#   '가까움',
#   '잡',
#   '플래닛',
#   '평점',
#   '믿',
#   '고',
#   '직접',
#   '겪',
#   '자는',
#   '생각',
#   '부질없',
#   '음',
#   '깨달',
#   '줌'],
#  ['주도',
#   '적',
#   '마케팅',
#   '기획',
#   '수립',
#   '가능',
#   '규모',
#   '회사',
#   '라',
#   '엄무',
#   '분업',
#   '음',
#   '마케팅',
#   '진행시',
#   '필수',
#   '인',
#   '커뮤니티',
#   '관리',
#   '음'],
#  ['옷',
#   '맘대로',
#   '입',
#   '어도',
#   '됨',
#   '슬리퍼',
#   '신고',
#   '출근',
#   '함',
#   '또래',
#   '많',
#   '아서',
#   '욕',
#   '기',
#   '좋',
#   '음'],
#  ['팀',
#   '만나',
#   '면',
#   '괜찮',
#   '음',
#   '단',
#   '팀원',
#   '한정',
#   '강남',
#   '위치',
#   '해서',
#   '밥집',
#   '종류',
#   '많',
#   '음'],
#  ['교육', '업계', '치', '고', '높', '연봉', '테이블', '교육', '지원', '됐', '던', '음'],
#  ['장점',
#   '는데',
#   '굳이',
#   '꼽',
#   '자면',
#   '연차',
#   '자유',
#   '롭',
#   '게',
#   '썼',
#   '던',
#   '고',
#   '직원',
#   '좋',
#   '았',
#   '다',
#   '내',
#   '속한',
#   '팀',
#   '야근',
#   '그렇게',
#   '많',
#   '진',
#   '았',
#   '다',
#   '팀',
#   '많',
#   '았',
#   '던',
#   '거',
#   '기'],
#  ['아침',
#   '식빵',
#   '우유',
#   '지급',
#   '직원',
#   '무료',
#   '강의',
#   '수강',
#   '가능',
#   '젊',
#   '사람',
#   '많',
#   '초년생',
#   '적응',
#   '기',
#   '쉬',
#   '움'],
#  ['사바',
#   '사',
#   '팀',
#   '다',
#   '팀',
#   '고',
#   '분위기',
#   '좋',
#   '팀',
#   '만나',
#   '면',
#   '좋',
#   '아요',
#   '그나마',
#   '복지',
#   '강남',
#   '다는',
#   '점',
#   '그것',
#   '괜찮'],
#  ['네임', '밸류', '좋', '고', '강남', '좋', '빌딩', '으니', '할', '맛', '난', '다', '인사', '느낌'],
#  ['업무',
#   '분담',
#   '확실',
#   '해서',
#   '체계',
#   '적',
#   '업무',
#   '처리',
#   '가능',
#   '함',
#   '수평',
#   '적',
#   '인',
#   '분위기',
#   '라',
#   '자유',
#   '롭',
#   '게',
#   '의견',
#   '낼',
#   '음',
#   '휴무',
#   '사용',
#   '시',
#   '자유',
#   '로움'],
#  ['업무', '분담', '철저', '고', '교육', '해줌', '학원', '강의', '다는', '점'],
#  ['개인',
#   '법',
#   '카로',
#   '야근',
#   '할',
#   '저녁',
#   '먹',
#   '었',
#   '음',
#   '밤',
#   '시',
#   '넘',
#   '으면',
#   '택시',
#   '비',
#   '지원',
#   '근데',
#   '매일',
#   '야근',
#   '해서',
#   '반갑',
#   '고',
#   '장점',
#   '란',
#   '건',
#   '모르',
#   '겠'],
#  ['장점', '그냥', '이름', '알려진', '곳', '라는', '이외', '엔', '네요'],
#  ['능률', '분위기', '프로', '운영', '좋', '다', '회식', '낮', '한다'],
#  ['연차',
#   '자유',
#   '롭',
#   '게',
#   '쓸',
#   '으며',
#   '칼',
#   '퇴',
#   '가능',
#   '함',
#   '업무',
#   '강도',
#   '높',
#   '으나',
#   '역량',
#   '승진',
#   '빠름'],
#  ['해고', '안', '함', '병가', '휴직', '공식', '적', '눈치', '안', '줌', '회식', '강요', '음'],
#  ['스케줄',
#   '근무',
#   '동료',
#   '협의',
#   '자유',
#   '롭',
#   '게',
#   '연차',
#   '쓸',
#   '고',
#   '기업',
#   '이름',
#   '이미지',
#   '어서',
#   '주위',
#   '사람',
#   '큰',
#   '기업',
#   '근무',
#   '한다는',
#   '인상',
#   '줄',
#   '음'],
#  ['대학교',
#   '분위기',
#   '여서',
#   '재미있',
#   '게',
#   '다닐',
#   '음',
#   '일부',
#   '사람',
#   '빼',
#   '고',
#   '밑',
#   '직원',
#   '대부분',
#   '착함',
#   '젊',
#   '분위기',
#   '임'],
#  ['전반',
#   '적',
#   '나이',
#   '어리',
#   '고',
#   '사람',
#   '다',
#   '좋',
#   '다',
#   '회사',
#   '생활',
#   '재미있',
#   '었',
#   '다'],
#  ['직원',
#   '젊',
#   '고',
#   '동기',
#   '많',
#   '음',
#   '식빵',
#   '간식',
#   '제공',
#   '야근',
#   '시',
#   '시간대',
#   '별',
#   '식대',
#   '택시',
#   '비',
#   '지원',
#   '해',
#   '줬',
#   '음'],
#  ['기업', '네임', '밸류', '다닌다고', '면', '알', '만', '곳', '임'],
#  ['아침',
#   '빵',
#   '이랑',
#   '우유',
#   '자취',
#   '중',
#   '인',
#   '미혼자',
#   '한해',
#   '먹',
#   '음',
#   '체계',
#   '아주',
#   '진',
#   '음',
#   '수평',
#   '적',
#   '인',
#   '분위기'],
#  ['공짜', '식빵', '쨈이', '구비', '음', '강남역', '번', '출구', '분', '거리'],
#  ['빵',
#   '준다',
#   '연차',
#   '달',
#   '번',
#   '쓴다',
#   '연차',
#   '수당',
#   '안',
#   '줘서',
#   '안',
#   '쓰',
#   '면',
#   '못',
#   '씀',
#   '단점',
#   '래',
#   '봐야',
#   '할',
#   '듯'],
#  ['퇴사',
#   '한지',
#   '됐',
#   '당시',
#   '교육',
#   '회사',
#   '비하',
#   '연봉',
#   '높',
#   '수준',
#   '었',
#   '아침',
#   '토스트',
#   '먹',
#   '게',
#   '좋',
#   '았었',
#   '고요'],
#  ['연차',
#   '윗사람',
#   '눈치',
#   '안',
#   '고',
#   '쓸',
#   '음',
#   '개인주의',
#   '적',
#   '인',
#   '분위기',
#   '맞',
#   '으면',
#   '편함'],
#  ['부서',
#   '보다',
#   '연구소',
#   '쪽',
#   '비교',
#   '적',
#   '업무',
#   '강',
#   '낮',
#   '듯',
#   '부서',
#   '너무',
#   '빡세',
#   '서',
#   '그런',
#   '거',
#   '쉽',
#   '진',
#   '음'],
#  ['젊', '직원', '연령', '대', '며', '자유', '로운', '회사', '분위기', '체계', '적', '배울', '환경'],
#  ['당시',
#   '재택',
#   '할',
#   '었',
#   '다는',
#   '장점',
#   '찾',
#   '기',
#   '란',
#   '어려운',
#   '갓',
#   '다',
#   '시키',
#   '대로',
#   '만',
#   '면',
#   '된다',
#   '생각',
#   '할',
#   '필요',
#   '다'],
#  ['정도',
#   '다니',
#   '면',
#   '연차',
#   '눈치',
#   '고',
#   '쓸',
#   '고',
#   '개인',
#   '적',
#   '인',
#   '문화',
#   '강하',
#   '다',
#   '니',
#   '단체',
#   '행사',
#   '그런',
#   '문화',
#   '강요',
#   '는다'],
#  ['모두',
#   '기업',
#   '사람',
#   '좋',
#   '고',
#   '신입',
#   '낸',
#   '의견',
#   '대해',
#   '고',
#   '반영',
#   '기',
#   '위해',
#   '조언',
#   '해',
#   '줌'],
#  ['직원',
#   '간',
#   '합심',
#   '분위기',
#   '좋',
#   '았',
#   '으며',
#   '부서',
#   '간',
#   '커뮤니케이션',
#   '원활',
#   '업무',
#   '적',
#   '인',
#   '시스템',
#   '구축',
#   '음'],
#  ['사람',
#   '젊',
#   '어서',
#   '좋',
#   '아요',
#   '윗사람',
#   '인해',
#   '스트레스',
#   '받',
#   '어요',
#   '바빠서',
#   '사람',
#   '친해질',
#   '기회',
#   '적',
#   '고',
#   '워낙',
#   '사람',
#   '많',
#   '고',
#   '자주',
#   '나가',
#   '고',
#   '신입',
#   '들어와서',
#   '개인플레이',
#   '고',
#   '싶',
#   '사람',
#   '좋',
#   '아요'],
#  ['강의', '공짜', '사람', '젊음', '그거', '고', '모르', '겠', '는데', '역', '가깝', '긴', '함'],
#  ['근로',
#   '조건',
#   '좋',
#   '국내',
#   '사교육',
#   '업계',
#   '위',
#   '기업',
#   '입니다',
#   '훌륭',
#   '선생',
#   '님',
#   '할',
#   '기회'],
#  ['회사',
#   '강남',
#   '위치',
#   '해서',
#   '접근성',
#   '좋',
#   '음',
#   '위',
#   '했',
#   '듯이',
#   '주위',
#   '사람',
#   '면',
#   '번',
#   '기업',
#   '다닌다는',
#   '자부심',
#   '느낄',
#   '음'],
#  ['꽤', '자유', '로운', '분위기', '다양', '사람', '다양', '업무', '경험', '가능', '합니다'],
#  ['그나마',
#   '직원',
#   '젊',
#   '다',
#   '다니',
#   '다',
#   '면',
#   '동아리',
#   '다니',
#   '느낌',
#   '든다',
#   '팀장',
#   '젊',
#   '어서',
#   '꼰대',
#   '적',
#   '고',
#   '나름',
#   '재밌',
#   '음'],
#  ['도서',
#   '비',
#   '구입',
#   '비',
#   '지원',
#   '야근',
#   '시',
#   '교통비',
#   '지원',
#   '그런',
#   '복지',
#   '부분',
#   '괜찮',
#   '음'],
#  ['교육', '업계', '탑', '들어가', '기업', '므로', '버티', '면', '커리어', '쌓', '기', '적합'],
#  ['교육',
#   '계',
#   '원탑',
#   '답',
#   '게',
#   '만큼',
#   '뿌듯',
#   '함',
#   '느낄',
#   '음',
#   '회사',
#   '분위기',
#   '좋',
#   '음'],
#  ['버티', '면', '직책', '빨리', '달', '음', '주변', '사람', '다', '질'],
#  ['개인', '적', '출퇴근', '기', '좋', '았', '다', '네임', '밸류', '어서', '이직', '할', '좋', '음'],
#  ['모르', '겠', '다', '사람', '젊', '다', '진짜', '어서', '모르', '겠', '음'],
#  ['능력', '입사', '대비', '빠른', '승진', '가능', '고', '멀티태스킹', '되게', '됨'],
#  ['퇴사',
#   '율',
#   '높',
#   '직원',
#   '연령',
#   '비슷',
#   '합니다',
#   '어려운',
#   '상사',
#   '문화',
#   '고',
#   '직원',
#   '간',
#   '소통',
#   '이루어지',
#   '편',
#   '입니다'],
#  ['식빵', '큰', '장점', '혼자', '서부터', '해', '볼', '음'],
#  ['연차',
#   '팀',
#   '바이',
#   '팀',
#   '상사',
#   '성향',
#   '자율',
#   '적',
#   '아닐',
#   '음',
#   '강남역',
#   '접근성',
#   '좋',
#   '음'],
#  ['네임',
#   '밸류',
#   '서',
#   '다닌다고',
#   '면',
#   '회사',
#   '월급',
#   '밀리',
#   '게',
#   '장점',
#   '인',
#   '회사',
#   '실무',
#   '투입',
#   '구조',
#   '때문',
#   '배우',
#   '기',
#   '좋',
#   '다'],
#  ['대표', '볼', '아예', '다', '강남역', '사무실', '뭐', '정도', '채우', '기', '너무', '듦'],
#  ['야근',
#   '시',
#   '빠른',
#   '승진',
#   '할',
#   '으나',
#   '수명',
#   '단축',
#   '됩니다',
#   '휴가',
#   '잠',
#   '만',
#   '잡',
#   '니다'],
#  ['연차',
#   '쓸',
#   '다',
#   '수평',
#   '적',
#   '분위기',
#   '존재',
#   '한다',
#   '좋',
#   '사람',
#   '많',
#   '다',
#   '간식',
#   '제공',
#   '고',
#   '강의',
#   '무료',
#   '다'],
#  ['직원', '연령', '대가', '대', '중', '후반', '이루', '고', '수평', '적', '고', '편안', '분위기'],
#  ['복지',
#   '라고',
#   '건',
#   '토스트',
#   '빵',
#   '미혼',
#   '면',
#   '우유',
#   '카페',
#   '프로',
#   '할인',
#   '학원',
#   '수업',
#   '무료',
#   '그다지',
#   '도움',
#   '안',
#   '됨'],
#  ['야근', '식대', '교통비', '지원', '해', '며', '강남역', '앞', '어서', '접근성', '좋', '음'],
#  ['정해진', '규칙', '대로', '생활', '기', '적합', '다', '자유', '롭', '다', '아침', '빵', '준다'],
#  ['월요일',
#   '금요일',
#   '만',
#   '근무',
#   '한다는',
#   '점',
#   '곤',
#   '음',
#   '장점',
#   '아무리',
#   '생각',
#   '해봐도',
#   '음',
#   '중',
#   '식도',
#   '월급',
#   '포함',
#   '어서',
#   '월급',
#   '남',
#   '게',
#   '그다지',
#   '음',
#   '기업',
#   '장점',
#   '쓰',
#   '라는',
#   '데',
#   '쓸',
#   '어서',
#   '참',
#   '난감',
#   '함'],
#  ['복장', '자유', '로움', '사업', '영역', '늘리', '고', '교육', '업계', '에선', '나름', '유명', '함'],
#  ['개인',
#   '디자인',
#   '역량',
#   '키우',
#   '기',
#   '위해',
#   '조직',
#   '시스템',
#   '갖추',
#   '려고',
#   '여러',
#   '가지',
#   '시도',
#   '합니다'],
#  ['회사', '위치', '강남역', '가깝', '다는', '점', '자사', '강의', '무료', '음'],
#  ['연차', '이런', '걸', '쓰', '게', '눈치', '보일', '음', '문서', '작업', '별'],
#  ['강남역', '라', '출퇴근', '교통', '우수', '함', '퇴근', '후', '약속', '잡', '기', '편함'],
#  ['엄청',
#   '편함',
#   '자기',
#   '만',
#   '면',
#   '외',
#   '시간',
#   '노터치',
#   '체계',
#   '잡혀',
#   '어서',
#   '외',
#   '안',
#   '해도',
#   '됨'],
#  ['아주', '가끔', '팀원', '팀장', '초특급', '승진', '경우', '음', '이유', '아무', '모름'],
#  ['장점', '라', '찾아보', '자면', '음', '모르', '겠', '강남역', '복판', '음'],
#  ['연차',
#   '사용',
#   '비교',
#   '적',
#   '자유',
#   '롭',
#   '달',
#   '번',
#   '강남역',
#   '가까워',
#   '출퇴근',
#   '편리',
#   '합니다',
#   '직원',
#   '또래',
#   '라',
#   '대부분',
#   '맞'],
#  ['유명',
#   '함',
#   '네임',
#   '밸류',
#   '좋',
#   '음',
#   '첫',
#   '회사',
#   '나쁘',
#   '음',
#   '인',
#   '강',
#   '무료',
#   '책',
#   '학인'],
#  ['젊', '분위기', '다', '직원', '다', '젊', '다', '보통', '대가', '이룸', '서울', '강남', '위치'],
#  ['최고',
#   '교육',
#   '그룹',
#   '해',
#   '커스',
#   '인',
#   '만큼',
#   '해',
#   '커스',
#   '진행',
#   '고',
#   '모든',
#   '수업',
#   '대한',
#   '할인',
#   '가능'],
#  ['팀원', '간', '사이', '정말', '좋', '았', '수평', '적', '인', '관계', '유지'],
#  ['장점',
#   '사실',
#   '그나마',
#   '강남역',
#   '출구',
#   '앞',
#   '위치',
#   '해서',
#   '교통',
#   '좋',
#   '다는',
#   '점',
#   '장점',
#   '라고',
#   '할',
#   '팀',
#   '별',
#   '규모',
#   '크',
#   '아서',
#   '인지',
#   '신입',
#   '견도',
#   '편',
#   '입니다',
#   '퇴사',
#   '너무',
#   '잦',
#   '아서',
#   '빨리',
#   '승진',
#   '할',
#   '편',
#   '입니다'],
#  ['역', '가깝', '다', '복장', '자율', '다', '아무리', '생각', '해도', '장점', '더', '다'],
#  ['강남', '위치', '사람', '젊', '어서', '재밌', '게', '할', '음', '사람', '착한', '편'],
#  ['연차',
#   '비교',
#   '적',
#   '자유',
#   '롭',
#   '게',
#   '사용',
#   '할',
#   '으나',
#   '이틀',
#   '붙여서',
#   '사용',
#   '려면',
#   '별도',
#   '사유',
#   '관리자',
#   '확인',
#   '필요',
#   '함',
#   '불',
#   '필요',
#   '회의',
#   '서면',
#   '보고',
#   '필요',
#   '음'],
#  ['팀',
#   '바이',
#   '팀',
#   '겠',
#   '자기',
#   '할',
#   '마치',
#   '면',
#   '눈치',
#   '안',
#   '고',
#   '퇴근',
#   '가능',
#   '깨끗',
#   '사무실',
#   '역세',
#   '권',
#   '정신',
#   '적',
#   '스트레스',
#   '었',
#   '음',
#   '비교',
#   '적',
#   '수평',
#   '적',
#   '인',
#   '분위기'],
#  ['휴무',
#   '자유',
#   '롭',
#   '게',
#   '쓸',
#   '음',
#   '달',
#   '회',
#   '매달',
#   '교육',
#   '혜택',
#   '제공',
#   '인강',
#   '음',
#   '신청',
#   '필요'],
#  ['강남역',
#   '가까운',
#   '거',
#   '고',
#   '사람',
#   '또래',
#   '라서',
#   '좋',
#   '으나',
#   '회사',
#   '애정',
#   '다',
#   '니',
#   '서로',
#   '대충',
#   '고',
#   '미루',
#   '고',
#   '감정',
#   '상',
#   '합니다'],
#  ['강남',
#   '중심',
#   '위치',
#   '함',
#   '해',
#   '커스',
#   '강의',
#   '무료',
#   '음',
#   '명절',
#   '시',
#   '선물',
#   '택배',
#   '배송',
#   '됨',
#   '식빵',
#   '잼',
#   '제공',
#   '됨',
#   '명함',
#   '할인',
#   '받',
#   '곳',
#   '음',
#   '뭐',
#   '을까'],
#  ['업무', '라는', '팀', '가장', '장점', '오래', '다닐', '었', '던', '이유', '라고', '생각', '함'],
#  ['본인',
#   '주어진',
#   '만',
#   '일정',
#   '맞',
#   '게',
#   '소화',
#   '퇴근',
#   '눈치',
#   '안',
#   '고',
#   '할',
#   '음',
#   '주로',
#   '대학생',
#   '밀접',
#   '게',
#   '다',
#   '니',
#   '활력',
#   '얻',
#   '부분',
#   '음',
#   '동료',
#   '나이',
#   '비슷',
#   '다',
#   '니',
#   '소통',
#   '데',
#   '어서',
#   '큰',
#   '지장',
#   '음',
#   '강남',
#   '다',
#   '니',
#   '강남',
#   '오피스',
#   '라이프',
#   '느낄',
#   '다'],
#  ['학원', '수업', '무료', '다', '학원', '수강', '생', '누리', '혜택', '비슷', '게', '누림'],
#  ['또래', '많', '아서', '좋', '친구', '사귈', '다', '만난', '사람', '라', '정말', '친해질', '다'],
#  ['직원',
#   '분',
#   '좋',
#   '그나마',
#   '기',
#   '좋',
#   '야근',
#   '별로',
#   '기',
#   '때문',
#   '본인',
#   '시간',
#   '많이',
#   '가질',
#   '아침',
#   '우유',
#   '빵',
#   '제공',
#   '합니다',
#   '모든',
#   '직원',
#   '알',
#   '고',
#   '었',
#   '미혼',
#   '인',
#   '자취생',
#   '만',
#   '제공',
#   '함'],
#  ['자기',
#   '계발',
#   '할',
#   '슈',
#   '비용',
#   '지원',
#   '해',
#   '줌',
#   '교육',
#   '계열',
#   '라서',
#   '원래',
#   '공부',
#   '던',
#   '내용',
#   '일치',
#   '해서',
#   '좋',
#   '았',
#   '음'],
#  ['비슷', '연령', '대', '직원', '구성', '어서', '동료', '관계', '부담', '음'],
#  ['여성',
#   '대한',
#   '차별',
#   '대우',
#   '못',
#   '느꼈',
#   '고',
#   '팀',
#   '분위기',
#   '수평',
#   '적',
#   '어서',
#   '좋',
#   '음',
#   '기업',
#   '이미지',
#   '취진',
#   '생',
#   '학생',
#   '좋',
#   '게',
#   '자리',
#   '잡',
#   '고',
#   '어서',
#   '외부',
#   '바라보',
#   '브랜드',
#   '이미지',
#   '나쁘',
#   '편',
#   '단순',
#   '보고',
#   '위한',
#   '문서',
#   '작업',
#   '으나',
#   '타',
#   '회사',
#   '비해서',
#   '간결',
#   '편',
#   '아날로그',
#   '적',
#   '인',
#   '문서',
#   '작업',
#   '어서',
#   '좋',
#   '음',
#   '강남역',
#   '근처',
#   '라',
#   '코로나',
#   '전',
#   '퇴근',
#   '후',
#   '놀',
#   '기',
#   '좋',
#   '았',
#   '음',
#   '교통',
#   '편리',
#   '함'],
#  ['수평', '적', '인', '사무실', '분위기', '팀원', '끼리', '사이좋', '고', '다', '괜찮', '음'],
#  ['업계', '위', '탑', '라는', '점', '회사', '위치', '학원', '수업', '무료', '음'],
#  ['냉장고',
#   '음',
#   '레',
#   '인지',
#   '음',
#   '정수기',
#   '음',
#   '장점',
#   '는데',
#   '이나',
#   '써야',
#   '는지',
#   '모르',
#   '겠',
#   '어요',
#   '정말',
#   '거든요',
#   '사람',
#   '착해요'],
#  ['젊',
#   '분위기',
#   '다',
#   '면',
#   '이것저것',
#   '배우',
#   '게',
#   '많',
#   '음',
#   '서',
#   '바',
#   '티',
#   '고',
#   '다',
#   '데',
#   '면',
#   '애',
#   '될',
#   '음'],
#  ['시급',
#   '높',
#   '았',
#   '으며',
#   '별관',
#   '상주',
#   '정말',
#   '앉',
#   '다가',
#   '용품',
#   '채우',
#   '고',
#   '수강',
#   '생',
#   '문',
#   '면'],
#  ['빵', '줌', '연차', '자유', '로운', '편', '진짜', '장점', '모르', '겠', '다'],
#  ['기업',
#   '임도',
#   '인지',
#   '덕',
#   '사람',
#   '이름',
#   '만',
#   '해도',
#   '알',
#   '고',
#   '강남역',
#   '가까워',
#   '대중교통',
#   '이용',
#   '수월',
#   '급여',
#   '아침',
#   '일찍',
#   '들어옴'],
#  ['강남역', '다', '정도', '빵', '무료', '다', '정도', '화장실', '휴지', '다', '정도'],
#  ['회사',
#   '아래',
#   '김밥',
#   '집',
#   '식비',
#   '지원',
#   '야근',
#   '시',
#   '택시',
#   '비',
#   '지원',
#   '너무',
#   '어서',
#   '직원',
#   '끼리',
#   '사이',
#   '좋',
#   '편',
#   '팀',
#   '마다',
#   '다를'],
#  ['회사',
#   '다니',
#   '면서',
#   '제일',
#   '크',
#   '게',
#   '얻',
#   '최고',
#   '복지',
#   '사람',
#   '직책',
#   '으며',
#   '생각',
#   '보다',
#   '수평',
#   '적',
#   '인',
#   '문화'],
#  ['젊음',
#   '근데',
#   '으쌰',
#   '으쌰',
#   '분위기',
#   '고',
#   '할',
#   '거',
#   '면',
#   '댐',
#   '그런',
#   '거',
#   '좋',
#   '면',
#   '괜찮',
#   '듯'],
#  ['다', '자는', '너무', '많', '다', '빵', '우유', '는데', '지금', '모르', '겠', '다'],
#  ['이름', '면', '대', '기업', '인', '줄', '앎', '팀', '내', '분위기', '좋', '았', '음'],
#  ['수평', '적', '문화', '어학원', '지원', '서구', '입', '지원', '됨', '강남역', '가까움'],
#  ['또래',
#   '많',
#   '즐겁',
#   '게',
#   '회사',
#   '생활',
#   '고',
#   '카페',
#   '아래',
#   '좋',
#   '고',
#   '영어',
#   '강의',
#   '다'],
#  ['어학',
#   '지겹',
#   '도록',
#   '해도',
#   '지겨워',
#   '사람',
#   '보람차',
#   '게',
#   '할',
#   '다',
#   '신입',
#   '많',
#   '양',
#   '배울',
#   '다',
#   '여러',
#   '사람',
#   '지도',
#   '받',
#   '기',
#   '때문',
#   '모든',
#   '의견',
#   '반영',
#   '여야',
#   '며',
#   '인해',
#   '다양',
#   '시야',
#   '수용',
#   '능력',
#   '기를',
#   '다',
#   '오래',
#   '버티',
#   '면',
#   '업계',
#   '인정받',
#   '곳'],
#  ['음',
#   '최소',
#   '쓰',
#   '라고',
#   '해서',
#   '굳이',
#   '쓰',
#   '자면',
#   '다',
#   '젊',
#   '어서',
#   '꼰대',
#   '문화',
#   '이런',
#   '건',
#   '었',
#   '던',
#   '듯'],
#  ['장점',
#   '아무리',
#   '생각',
#   '해',
#   '려고',
#   '머리',
#   '쥐',
#   '짜내',
#   '봤',
#   '는데',
#   '해',
#   '커스',
#   '라는',
#   '브랜드',
#   '네임',
#   '밸류',
#   '빼',
#   '곤',
#   '음'],
#  ['대', '기업', '라는', '거', '해', '커스', '강의', '다는', '게', '굳이', '뽑', '자면', '장점'],
#  ['그나마', '뽑', '자면', '휴양소', '싸', '게', '갈', '거', '다', '쓰', '기', '드'],
#  ['아무래도',
#   '학원',
#   '업종',
#   '다',
#   '니',
#   '직원',
#   '연령',
#   '대',
#   '낮',
#   '팀',
#   '내',
#   '분위기',
#   '화목',
#   '함'],
#  ['사람',
#   '다양',
#   '업무',
#   '맡',
#   '아서',
#   '기',
#   '때문',
#   '업무',
#   '스킬',
#   '향상',
#   '이직',
#   '면',
#   '한다',
#   '소리',
#   '다',
#   '연령',
#   '대',
#   '어려',
#   '회사',
#   '라',
#   '기보단',
#   '학교',
#   '다니',
#   '마음',
#   '할',
#   '다',
#   '회사',
#   '규모',
#   '크',
#   '고',
#   '비용',
#   '아끼',
#   '편',
#   '어서',
#   '다양',
#   '시도',
#   '해',
#   '볼',
#   '다'],
#  ['연차',
#   '쓰',
#   '는데',
#   '눈치',
#   '안',
#   '줌',
#   '달',
#   '번',
#   '무조건',
#   '휴무',
#   '사람',
#   '모두',
#   '좋',
#   '편'],
#  ['식빵',
#   '제공',
#   '직원',
#   '다',
#   '젊',
#   '편',
#   '라',
#   '나름',
#   '분위기',
#   '밝',
#   '편',
#   '네임',
#   '밸류',
#   '다는',
#   '점'],
#  ['무료', '제공', '인강', '개', '고', '월급', '꼬박꼬박', '제때', '나옵니다'],
#  ['사업',
#   '기반',
#   '안정',
#   '적',
#   '고',
#   '많',
#   '사람',
#   '알',
#   '고',
#   '인지',
#   '기업',
#   '다',
#   '업계',
#   '분야',
#   '위',
#   '다'],
#  ['온라인',
#   '강의',
#   '오프라인',
#   '강의',
#   '무료',
#   '파리바',
#   '게',
#   '뜨',
#   '식빵',
#   '공짜',
#   '강남역',
#   '위치',
#   '옆',
#   '라면',
#   '집',
#   '맛있',
#   '음',
#   '젊',
#   '연령',
#   '대',
#   '연차',
#   '쓰',
#   '면',
#   '눈치',
#   '콘',
#   '리조트',
#   '공짜',
#   '선착순',
#   '누군가',
#   '다니',
#   '냐',
#   '물으면',
#   '이런',
#   '반응',
#   '일으키',
#   '브랜드',
#   '효과'],
#  ['솔직',
#   '정말',
#   '어요',
#   '정수기',
#   '랑',
#   '토스트',
#   '거',
#   '수업',
#   '듣',
#   '고',
#   '싶',
#   '거',
#   '으면',
#   '거',
#   '야근',
#   '느라',
#   '신청',
#   '해도',
#   '못',
#   '어요'],
#  ['네임',
#   '밸류',
#   '좋',
#   '다',
#   '다양',
#   '업무',
#   '배울',
#   '다',
#   '홍보',
#   '기획',
#   '디자인',
#   '기획',
#   '강의',
#   '기획'],
#  ['줄', '평', '장점', '임', '나름', '체계', '적', '고', '기획', '교육', '지원', '굳'],
#  ['인지도', '높', '아서', '주변', '회사', '다니', '는지', '알', '다'],
#  ['이름',
#   '기',
#   '좋',
#   '고',
#   '교육',
#   '인',
#   '강',
#   '제공',
#   '데',
#   '기간',
#   '지난',
#   '거',
#   '제공',
#   '해',
#   '줌',
#   '위치',
#   '강남역',
#   '라',
#   '좋',
#   '음',
#   '회사',
#   '건물',
#   '올려서',
#   '하나',
#   '통합',
#   '시킨다고',
#   '는데',
#   '될지',
#   '모름',
#   '땅',
#   '사',
#   '놨다는',
#   '데',
#   '직원',
#   '갈',
#   '아서',
#   '오너',
#   '배',
#   '만',
#   '불리',
#   '거',
#   '긴',
#   '일단',
#   '건물',
#   '올라가',
#   '기',
#   '까진',
#   '걸릴',
#   '턴데',
#   '내',
#   '전',
#   '나갈',
#   '듯',
#   '사내',
#   '문화',
#   '좋',
#   '음',
#   '사원',
#   '끼리',
#   '만'],
#  ['사람', '밝', '고', '젊', '어서', '장벽', '느껴', '는다', '사람', '좋', '고', '많', '다'],
#  ['강남역', '가까움', '네임', '밸류', '해', '커스', '라고', '했', '대부분', '알', '고', '음'],
#  ['당시', '연봉', '수준', '근속', '연수', '비해', '준', '합니다', '하나', '연차', '쌓이', '면'],
#  ['강남', '교통', '혼잡', '식빵', '무제한', '인데', '요즘', '그러', '려나'],
#  ['아랫사람', '끼리', '뭉쳐서', '끈끈', '해짐', '해', '커스', '라고', '면', '사람'],
#  ['젊', '사람', '많', '아서', '직장', '동료', '비슷', '나이', '대', '라서', '좋', '다'],
#  ['연차',
#   '쓰',
#   '안',
#   '쓰',
#   '똑같',
#   '아서',
#   '눈치',
#   '안',
#   '고',
#   '쓸',
#   '다',
#   '연휴',
#   '못',
#   '쓰',
#   '팀',
#   '다',
#   '팀',
#   '겠',
#   '팀',
#   '분위기',
#   '나쁘',
#   '다'],
#  ['업무', '분담', '확실', '고', '기업', '위치', '좋', '으며', '많', '배울', '게', '해줌'],
#  ['업무',
#   '일정',
#   '큰',
#   '무리',
#   '연차',
#   '사용',
#   '자유',
#   '롭',
#   '식빵',
#   '쨈',
#   '간식',
#   '휴가',
#   '저렴',
#   '가격',
#   '상당',
#   '멋진',
#   '숙소',
#   '대명',
#   '리조트',
#   '예약',
#   '할',
#   '강남',
#   '회사',
#   '교육',
#   '업',
#   '기',
#   '때문',
#   '업무',
#   '보람',
#   '자부심'],
#  ['휴양소', '이용', '할', '고', '학원', '수강료', '어학', '부분', '배울'],
#  ['장점',
#   '요',
#   '글쎄요',
#   '설',
#   '이나',
#   '추석',
#   '배',
#   '보내',
#   '거',
#   '부모',
#   '님',
#   '맛있',
#   '다고',
#   '좋',
#   '시',
#   '네요'],
#  ['연차', '눈치', '안', '고', '쓸', '음', '식빵', '무료', '제공', '자유', '로운', '분위기'],
#  ['직무',
#   '차이',
#   '대체로',
#   '매뉴얼',
#   '정리',
#   '으면',
#   '회사',
#   '비해',
#   '체계',
#   '적',
#   '정리',
#   '된',
#   '듯',
#   '함'],
#  ['다수',
#   '사람',
#   '회사',
#   '인',
#   '점',
#   '편한',
#   '복장',
#   '운동복',
#   '제외',
#   '많',
#   '업무',
#   '통해',
#   '업무',
#   '능력',
#   '향상'],
#  ['강남구',
#   '핵심',
#   '지역',
#   '위치',
#   '토스트',
#   '무한',
#   '먹',
#   '음',
#   '야근',
#   '면',
#   '날',
#   '플렉시블',
#   '라',
#   '해서',
#   '조금',
#   '늦',
#   '게',
#   '출근',
#   '해도',
#   '시스템',
#   '던',
#   '걸로',
#   '기억',
#   '함',
#   '젊',
#   '직원',
#   '많',
#   '음'],
#  ['강남',
#   '복판',
#   '으면',
#   '젊',
#   '사람',
#   '많',
#   '음',
#   '복장',
#   '편함',
#   '생각',
#   '보다',
#   '큰',
#   '회사',
#   '임'],
#  ['지하철',
#   '광고',
#   '많이',
#   '들리',
#   '고',
#   '웬만',
#   '주위',
#   '사람',
#   '들으면',
#   '회사',
#   '인지',
#   '다',
#   '안다는',
#   '점'],
#  ['여러', '경험', '해', '볼', '다', '여러', '복지', '실질', '적', '활용', '할', '건', '글쎄'],
#  ['주도', '적', '인', '업무', '진행', '정도', '수평', '적', '인', '관계', '다는', '점'],
#  ['오프라인', '학원', '무료', '수강', '가능', '다양', '업무', '가능', '플렉시블', '출근'],
#  ['업무',
#   '강도',
#   '쌔',
#   '고',
#   '턴',
#   '오버',
#   '심해',
#   '매뉴얼',
#   '적립',
#   '다',
#   '빠르',
#   '게',
#   '배울',
#   '으나',
#   '큰',
#   '발전',
#   '도모',
#   '기',
#   '어려운',
#   '회사',
#   '사원',
#   '인사이트',
#   '가이드라인',
#   '줄',
#   '능력',
#   '팀장',
#   '임',
#   '원급',
#   '음',
#   '다',
#   '어쩌다',
#   '자리',
#   '씩',
#   '고',
#   '듯',
#   '야근',
#   '팀부',
#   '팀',
#   '심하',
#   '다',
#   '복지',
#   '음',
#   '안',
#   '좋',
#   '회사',
#   '수록',
#   '다니',
#   '면서',
#   '이직',
#   '준비',
#   '기',
#   '란',
#   '어려우므로',
#   '업무',
#   '이직',
#   '준비',
#   '병행',
#   '불가',
#   '사회',
#   '초년생',
#   '라면',
#   '선택',
#   '길'],
#  ['음', '월급', '밀릴', '걱정', '없음', '강남역', '위치', '함', '젊', '친구', '많', '음'],
#  ['음', '취직', '쉬운', '거', '장점', '랄까', '쉽', '게', '들어와서', '싑', '게', '나감'],
#  ['젊',
#   '연령층',
#   '많',
#   '아서',
#   '동료',
#   '직원',
#   '지내',
#   '기',
#   '좋',
#   '환경',
#   '코로나',
#   '상황',
#   '질',
#   '규모',
#   '회사',
#   '라는',
#   '점'],
#  ['부서',
#   '마다',
#   '다르',
#   '겠',
#   '연차',
#   '최대한',
#   '눈치',
#   '안',
#   '고',
#   '쓸',
#   '음',
#   '업무',
#   '간단',
#   '해서',
#   '익',
#   '기',
#   '쉬움',
#   '교육',
#   '회사',
#   '다',
#   '니',
#   '교육',
#   '대한',
#   '기회',
#   '음'],
#  ['수평',
#   '적',
#   '인',
#   '사내',
#   '분위기',
#   '인생',
#   '친구',
#   '만들',
#   '음',
#   '상사',
#   '무',
#   '능력',
#   '고',
#   '윗선',
#   '빠른',
#   '퇴사',
#   '초고속',
#   '승진',
#   '가능'],
#  ['업무', '평판', '우수', '합니다', '일정', '경력', '후', '이직', '용이', '할'],
#  ['디자인', '운영', '많', '기', '때문', '다양', '경험', '해', '볼', '다', '경험', '된다'],
#  ['장점', '기억나', '음', '동료', '좋', '았', '던', '거', '음'],
#  ['식빵', '우유', '먹', '급여', '밀리', '고', '제때', '나옵니다'],
#  ['수평',
#   '적',
#   '인',
#   '분위기',
#   '부서',
#   '다',
#   '탈',
#   '퇴함',
#   '교통',
#   '편하',
#   '사람',
#   '너무',
#   '많',
#   '음'],
#  ['기업',
#   '장점',
#   '하나',
#   '꼽',
#   '자면',
#   '큰',
#   '곳',
#   '다',
#   '니',
#   '시스템',
#   '사용',
#   '기',
#   '쉽',
#   '게',
#   '갖춰져',
#   '음'],
#  ['야근',
#   '식대',
#   '심야',
#   '야근',
#   '시',
#   '택시',
#   '비',
#   '제공',
#   '체계',
#   '적',
#   '효율',
#   '적',
#   '인',
#   '업무',
#   '교육',
#   '시키',
#   '회사',
#   '회사',
#   '갔',
#   '능률',
#   '적',
#   '방법',
#   '알려줌'],
#  ['네임', '밸류', '서울', '복판', '다는', '거', '인터넷', '강의', '무료', '수강', '할', '다'],
#  ['강남역',
#   '위치',
#   '남',
#   '본',
#   '기업',
#   '교육',
#   '업',
#   '치곤',
#   '나쁘',
#   '급여',
#   '수준',
#   '승진',
#   '빠르',
#   '다'],
#  ['네이밍',
#   '많',
#   '사람',
#   '알',
#   '정도',
#   '큰',
#   '회사',
#   '라는',
#   '회사',
#   '이직',
#   '할',
#   '유리',
#   '할',
#   '거'],
#  ['법',
#   '적',
#   '문제',
#   '될',
#   '만',
#   '절대',
#   '음',
#   '내',
#   '연봉',
#   '안',
#   '올라도',
#   '남',
#   '좋',
#   '직장',
#   '인',
#   '줄',
#   '앎',
#   '월급',
#   '절대',
#   '안',
#   '밀림',
#   '어쨌든',
#   '기업',
#   '가치',
#   '올라갈',
#   '듯'],
#  ['연차',
#   '관계없이',
#   '다양',
#   '해',
#   '볼',
#   '고',
#   '여러',
#   '가지',
#   '시도',
#   '해',
#   '볼',
#   '연차',
#   '눈치',
#   '없이',
#   '사용',
#   '할'],
#  ['강남역',
#   '가까워',
#   '출퇴근',
#   '시',
#   '용이',
#   '함',
#   '토스트',
#   '잼',
#   '제공',
#   '퇴사',
#   '많',
#   '신입',
#   '인',
#   '경우',
#   '파트',
#   '장',
#   '진급',
#   '할',
#   '음'],
#  ['비슷',
#   '또래',
#   '집단',
#   '사이',
#   '서로',
#   '으쌰',
#   '으쌰',
#   '할',
#   '음',
#   '분위기',
#   '좋',
#   '팀',
#   '바',
#   '팀'],
#  ['네임', '밸류', '회사', '위치', '좋', '음', '젊', '분위기'],
#  ['무료', '강의', '수강', '할', '점', '대부분', '직원', '친절', '함'],
#  ['직원', '존중', '해', '수평', '적', '분위기', '형성', '스트레스', '받', '고', '다닐', '었', '다'],
#  ['안정',
#   '적',
#   '라고',
#   '느낀다',
#   '능력',
#   '중심',
#   '팀',
#   '바이',
#   '팀',
#   '라',
#   '매출',
#   '내',
#   '팀',
#   '능력',
#   '거품',
#   '낀다'],
#  ['손가락', '매우', '빨라짐', '강남', '사', '사람', '가까운', '편'],
#  ['수당',
#   '정확',
#   '챙겨',
#   '줍니다',
#   '아르바이트',
#   '한정',
#   '당연',
#   '소리',
#   '연장',
#   '수당',
#   '챙겨',
#   '곳',
#   '기에',
#   '난이도',
#   '어렵'],
#  ['다',
#   '고생',
#   '고',
#   '어서',
#   '사람',
#   '끼리',
#   '친함',
#   '교통',
#   '편리',
#   '함',
#   '해커',
#   '스',
#   '인',
#   '강',
#   '공짜',
#   '음',
#   '외국어',
#   '종류'],
#  ['젊',
#   '층',
#   '해서',
#   '분위기',
#   '좋',
#   '음',
#   '들어도',
#   '사람',
#   '때문',
#   '버팀',
#   '젊',
#   '나이',
#   '장',
#   '달수',
#   '음'],
#  ['음', '젊', '사람', '많이', '고', '출퇴근', '지하철역', '가까움'],
#  ['연차',
#   '사용',
#   '자유',
#   '롭',
#   '정도',
#   '기준',
#   '완화',
#   '긴',
#   '함',
#   '인정받',
#   '으면',
#   '연봉',
#   '직책',
#   '인정',
#   '해',
#   '줌',
#   '사무실',
#   '환경',
#   '나쁘',
#   '진',
#   '음'],
#  ['장점',
#   '진짜',
#   '는데',
#   '그냥',
#   '강남',
#   '라는',
#   '거',
#   '해',
#   '커스',
#   '강의',
#   '는데',
#   '절대',
#   '시간',
#   '불가'],
#  ['사내',
#   '강의',
#   '음',
#   '레',
#   '인지',
#   '음',
#   '아침',
#   '빵',
#   '줌',
#   '강남역',
#   '복판',
#   '지하철역',
#   '가까움',
#   '퇴근',
#   '고',
#   '주변',
#   '놀',
#   '데',
#   '많',
#   '음',
#   '약속',
#   '잡',
#   '기',
#   '편함'],
#  ['좋',
#   '아요',
#   '연차',
#   '장',
#   '로고',
#   '연차',
#   '써도',
#   '아무',
#   '눈치',
#   '안',
#   '고',
#   '휴가',
#   '적절',
#   '며',
#   '좋',
#   '기업',
#   '입니다',
#   '항상',
#   '감사',
#   '고',
#   '좋',
#   '았'],
#  ['연차',
#   '윗사람',
#   '눈치',
#   '안',
#   '고',
#   '쓸',
#   '는지',
#   '모른다',
#   '윗글',
#   '마찬가지',
#   '기업',
#   '리뷰',
#   '기',
#   '글',
#   '적',
#   '중'],
#  ['강남',
#   '주변',
#   '놀',
#   '게',
#   '많',
#   '아서',
#   '좋',
#   '다',
#   '사람',
#   '다',
#   '젊',
#   '다',
#   '그래서인지',
#   '자유',
#   '로운',
#   '분위기',
#   '다',
#   '업무',
#   '시간',
#   '커피',
#   '사',
#   '러',
#   '나가',
#   '고',
#   '빵',
#   '사',
#   '러',
#   '나가',
#   '고',
#   '간식',
#   '사',
#   '러',
#   '나가',
#   '고',
#   '아주',
#   '자유',
#   '로운',
#   '데',
#   '지금',
#   '그런지는',
#   '모르',
#   '겠',
#   '다'],
#  ['강남역', '가깝', '고', '식빵', '제공', '거', '송년회', '화려', '게', '함'],
#  ['연차',
#   '눈치',
#   '안',
#   '고',
#   '쓸',
#   '주전',
#   '면',
#   '됩니다',
#   '직장',
#   '동료',
#   '젊',
#   '회사',
#   '튼튼',
#   '해서',
#   '월급',
#   '나옵니다',
#   '어려운',
#   '점',
#   '든',
#   '점',
#   '팀장',
#   '님',
#   '동료',
#   '지원',
#   '받',
#   '고',
#   '공유',
#   '합니다'],
#  ['조직',
#   '적',
#   '고',
#   '기업',
#   '규모',
#   '괜찮',
#   '음',
#   '갑자기',
#   '망할',
#   '고',
#   '사람',
#   '좋',
#   '사람',
#   '많',
#   '았',
#   '음'],
#  ['매달',
#   '막바지',
#   '쯤',
#   '다',
#   '모여서',
#   '쉬',
#   '날',
#   '정했',
#   '다',
#   '아침',
#   '빵',
#   '준다',
#   '그게',
#   '다',
#   '인',
#   '듯'],
#  ['버티',
#   '면',
#   '연차',
#   '좋',
#   '직급',
#   '업무',
#   '경험',
#   '해',
#   '볼',
#   '다',
#   '그만큼',
#   '책임질',
#   '많',
#   '짐'],
#  ['부서',
#   '바이',
#   '부서',
#   '칼',
#   '퇴',
#   '웬만',
#   '면',
#   '가능',
#   '함',
#   '강남',
#   '근무지',
#   '위치',
#   '해',
#   '다는',
#   '장점'],
#  ['연령',
#   '대',
#   '낮',
#   '승진',
#   '빠르',
#   '고',
#   '회식',
#   '음',
#   '복장',
#   '자유',
#   '로운',
#   '편',
#   '위치',
#   '강남역',
#   '출구',
#   '인근',
#   '어서',
#   '매우',
#   '좋',
#   '음'],
#  ['정수기', '화장실', '의자', '책상', '컴퓨터', '다', '최소', '도저', '채울', '네요'],
#  ['임원', '프로', '끼리', '웃', '으면서', '재밌', '게', '지내', '모습', '꼴', '기', '싫어함'],
#  ['대부분',
#   '연령',
#   '어려',
#   '무겁',
#   '분위기',
#   '팀',
#   '별',
#   '분위기',
#   '다르',
#   '긴',
#   '전반',
#   '적',
#   '자유',
#   '로운',
#   '분위기',
#   '인',
#   '건',
#   '좋',
#   '다'],
#  ['비슷', '나이', '대로', '비교', '적', '수평', '적', '인', '분위기', '강남', '위치', '함'],
#  ['다양', '배울', '다', '보안', '다'],
#  ['장점', '라고', '할', '게', '음', '회사', '네임', '밸류', '교통편', '그게', '전부'],
#  ['역',
#   '가까움',
#   '건물',
#   '깨끗',
#   '함',
#   '사람',
#   '직',
#   '률',
#   '높',
#   '아서',
#   '승진',
#   '기회',
#   '높',
#   '짐'],
#  ['아르바이트', '근무', '일정', '조정', '비교', '적', '쉬움', '월급', '루', '팡', '기', '좋', '음'],
#  ['가족', '분위기', '평등', '문화', '직급', '통일', '재미', '었', '던', '체육', '대회'],
#  ['업무', '체계', '잡혀', '다', '서', '적응', '면', '곳', '적응', '할', '듯'],
#  ['어학원',
#   '강의',
#   '랑',
#   '인강',
#   '번',
#   '많',
#   '걸',
#   '요구',
#   '해',
#   '내',
#   '한계',
#   '까진가',
#   '도전',
#   '게',
#   '만들',
#   '줌'],
#  ['강남',
#   '점',
#   '장점',
#   '회식',
#   '고',
#   '다',
#   '해도',
#   '술',
#   '강요',
#   '안',
#   '함',
#   '젊',
#   '사람',
#   '많',
#   '아서',
#   '동료',
#   '공감대',
#   '형성',
#   '됨'],
#  ['가장',
#   '큰',
#   '장점',
#   '퇴사',
#   '율',
#   '높',
#   '내',
#   '위',
#   '골',
#   '때리',
#   '선임',
#   '빨리빨리',
#   '사라진다는',
#   '다',
#   '이걸',
#   '장점',
#   '라고',
#   '할',
#   '을지',
#   '모르',
#   '겠',
#   '대신',
#   '내',
#   '해',
#   '줄',
#   '후임',
#   '빨리빨리',
#   '사라진다',
#   '모든',
#   '상황',
#   '악물',
#   '고',
#   '만',
#   '버티',
#   '면',
#   '팀장',
#   '까진',
#   '어도',
#   '해당',
#   '팀',
#   '최고',
#   '선임',
#   '가능',
#   '다',
#   '마디',
#   '승진',
#   '빠르',
#   '다',
#   '회사',
#   '경험',
#   '기',
#   '든',
#   '직책',
#   '이나',
#   '경험',
#   '주도',
#   '적',
#   '해',
#   '볼',
#   '다는',
#   '장점',
#   '다',
#   '회사',
#   '처럼',
#   '휴가',
#   '시',
#   '리조트',
#   '혜택',
#   '받',
#   '고',
#   '외',
#   '엔',
#   '장점',
#   '은데',
#   '굳이',
#   '짜내',
#   '자면',
#   '식빵',
#   '잼',
#   '구워',
#   '먹',
#   '도록',
#   '상시',
#   '제공',
#   '고',
#   '자취생',
#   '우유',
#   '준다',
#   '명절',
#   '상여',
#   '어차피',
#   '연봉',
#   '포함',
#   '고',
#   '명절',
#   '선물',
#   '과일',
#   '박스',
#   '정도',
#   '준다'],
#  ['식빵',
#   '우유',
#   '줌',
#   '우유',
#   '미혼',
#   '자취생',
#   '기준',
#   '신청',
#   '해야',
#   '함',
#   '해',
#   '커스',
#   '인강',
#   '실강',
#   '무료',
#   '매월',
#   '신청',
#   '팀',
#   '평균',
#   '연령',
#   '대',
#   '후반',
#   '팀',
#   '다',
#   '팀',
#   '대부분',
#   '젊음'],
#  ['강남',
#   '어서',
#   '업무',
#   '외',
#   '시간',
#   '놀',
#   '곳',
#   '많',
#   '았',
#   '다',
#   '부서',
#   '마다',
#   '다르',
#   '겠',
#   '수평',
#   '적',
#   '었',
#   '음'],
#  ['중견',
#   '기업',
#   '고',
#   '규모',
#   '크',
#   '다',
#   '니까',
#   '인수인계',
#   '라던가',
#   '시스템',
#   '상당',
#   '체계',
#   '적',
#   '갖춰져',
#   '다고',
#   '생각',
#   '한다'],
#  ['강남역', '분', '거리', '교통편', '좋', '음', '신', '사옥', '생기', '면', '복지', '나아질', '듯'],
#  ['수평', '적', '인', '분위기', '강남역', '근접', '위치', '대부분', '개별', '업무', '진행', '됨'],
#  ['부서',
#   '팀',
#   '마다',
#   '다르',
#   '겠',
#   '근무',
#   '했',
#   '던',
#   '곳',
#   '전반',
#   '적',
#   '연령',
#   '대',
#   '낮',
#   '아서',
#   '팀원',
#   '소통',
#   '이루어지',
#   '편',
#   '었',
#   '음'],
#  ['젊',
#   '직원',
#   '많',
#   '의사',
#   '관계',
#   '수평',
#   '적',
#   '고',
#   '예외',
#   '소수',
#   '다',
#   '내',
#   '직접',
#   '주요',
#   '프로젝트',
#   '많',
#   '체험',
#   '해',
#   '볼',
#   '음'],
#  ['젊', '기업', '추구', '려', '합니다', '모르', '겠'],
#  ['회사', '강남', '위치', '해', '다', '직원', '연령', '대', '낮', '고', '비슷', '다'],
#  ['위치', '강남', '한강', '이남', '사', '서울', '사람', '매우', '이득', '거기'],
#  ['생각',
#   '보다',
#   '인지도',
#   '높',
#   '음',
#   '모든',
#   '직군',
#   '직무',
#   '경험',
#   '쌓',
#   '기',
#   '엔',
#   '좋',
#   '을지'],
#  ['인지도',
#   '높',
#   '기업',
#   '설명',
#   '도움',
#   '된다',
#   '직원',
#   '연령',
#   '대',
#   '낮',
#   '직원',
#   '간',
#   '소통',
#   '쉽',
#   '다'],
#  ['정말', '많', '다양', '업무', '실무', '진행', '할', '어요'],
#  ['교육산업', '학원', '대한', '좋', '경험', '할', '으면', '큰', '학원', '장점'],
#  ['연령',
#   '대',
#   '비슷비슷',
#   '해서',
#   '사람',
#   '끼리',
#   '친함',
#   '사원',
#   '좋',
#   '아요',
#   '사람',
#   '만',
#   '좋',
#   '아요'],
#  ['던',
#   '거',
#   '은데',
#   '굳이',
#   '자면',
#   '교육',
#   '무료',
#   '거',
#   '근데',
#   '시간',
#   '어서',
#   '못함',
#   '야근',
#   '매일',
#   '니까'],
#  ['교육', '관해', '뜻', '다면', '많이', '할', '고', '배울', '점', '다'],
#  ['학원',
#   '다',
#   '니',
#   '회사',
#   '위치',
#   '좋',
#   '음',
#   '교통',
#   '편리',
#   '근처',
#   '식당',
#   '저렴',
#   '고',
#   '다양',
#   '게',
#   '꾸려져',
#   '음'],
#  ['었', '다', '강남', '위치', '함', '점', '정도', '외', '음', '해', '커스', '면', '다', '정도'],
#  ['강남역', '거', '쓸', '다', '진짜', '채울', '다'],
#  ['초반',
#   '너무',
#   '많',
#   '업무',
#   '량',
#   '보이',
#   '자잘',
#   '헌',
#   '업무',
#   '많',
#   '았',
#   '다',
#   '거',
#   '임',
#   '익숙',
#   '해',
#   '기',
#   '만',
#   '면',
#   '뭐',
#   '무난',
#   '게',
#   '다닐',
#   '으면',
#   '낡',
#   '기업',
#   '이나',
#   '인프라',
#   '굿',
#   '군',
#   '라고',
#   '봄',
#   '기획',
#   '걸',
#   '실현',
#   '해',
#   '나갈',
#   '음'],
#  ['월급',
#   '떼먹',
#   '고',
#   '준다',
#   '수평',
#   '적',
#   '다',
#   '공정',
#   '평가',
#   '신입',
#   '주도',
#   '적',
#   '할',
#   '업무',
#   '준다'],
#  ['또래', '많', '아서', '즐겁', '게', '다닐', '었', '다', '빌', '런', '었'],
#  ['강남역',
#   '라는',
#   '우수',
#   '접근성',
#   '신입',
#   '시기',
#   '회사',
#   '생활',
#   '듦을',
#   '강하',
#   '게',
#   '받',
#   '데',
#   '면',
#   '웬만큼',
#   '적응',
#   '할',
#   '음'],
#  ['자유',
#   '로운',
#   '분위기',
#   '성',
#   '지향',
#   '욕심',
#   '다면',
#   '성장',
#   '가능',
#   '퍼포먼스',
#   '부풀리',
#   '방법',
#   '배울',
#   '다'],
#  ['서울',
#   '강남',
#   '복판',
#   '위치',
#   '먹',
#   '곳',
#   '많',
#   '고',
#   '볼',
#   '거리',
#   '많',
#   '편',
#   '다',
#   '약속',
#   '잡',
#   '기',
#   '편리',
#   '다'],
#  ['다양', '할', '점', '사회', '초년생', '괜찮', '점', '음'],
#  ['어쨌든',
#   '유명',
#   '기',
#   '때문',
#   '그게',
#   '장점',
#   '다',
#   '식빵',
#   '줬',
#   '다',
#   '아직',
#   '그런지는',
#   '모르',
#   '겠',
#   '음'],
#  ['해커', '스', '인', '만큼', '해', '커스', '진행', '교육', '대한', '할인', '받', '다는'],
#  ['강남역',
#   '위치',
#   '명확',
#   '업무',
#   '프로세스',
#   '재택근무',
#   '가능',
#   '시스템',
#   '젊',
#   '사람',
#   '기업',
#   '인',
#   '지도',
#   '편',
#   '대학교',
#   '또래',
#   '집단'],
#  ['간식',
#   '식빵',
#   '우유',
#   '먹',
#   '다',
#   '장점',
#   '는데',
#   '장점',
#   '쓰',
#   '라고',
#   '니',
#   '서울',
#   '근무지',
#   '게',
#   '장점',
#   '일까'],
#  ['또래',
#   '많',
#   '아서',
#   '복장',
#   '이나',
#   '분위기',
#   '자유',
#   '로운',
#   '편',
#   '고',
#   '자기',
#   '계발',
#   '토익',
#   '토스',
#   '할인',
#   '돼요',
#   '직원',
#   '한정'],
#  ['교육',
#   '기업',
#   '중',
#   '에선',
#   '이름',
#   '기업',
#   '라',
#   '회사',
#   '명만',
#   '해도',
#   '대부분',
#   '기업',
#   '신입',
#   '교육',
#   '괜찮',
#   '음'],
#  ['교육',
#   '업계',
#   '신입',
#   '높',
#   '연봉',
#   '기업',
#   '비해',
#   '젊',
#   '조직',
#   '구성',
#   '음',
#   '신입',
#   '많',
#   '해',
#   '볼',
#   '음'],
#  ['내',
#   '공간',
#   '편함',
#   '팀원',
#   '끼리',
#   '분위기',
#   '나름',
#   '좋',
#   '음',
#   '대',
#   '기업',
#   '복지',
#   '좋',
#   '음'],
#  ['신청',
#   '면',
#   '무료',
#   '학원',
#   '강의',
#   '또는',
#   '인터넷',
#   '강의',
#   '복지',
#   '음',
#   '정말',
#   '바빴',
#   '많이',
#   '배울',
#   '기',
#   '했',
#   '음'],
#  ['그나마',
#   '괜찮',
#   '게',
#   '기',
#   '전',
#   '연차',
#   '반차',
#   '쓸지',
#   '정도',
#   '미리',
#   '받',
#   '아서',
#   '보통',
#   '다',
#   '해',
#   '려고',
#   '노력',
#   '함',
#   '맘대로',
#   '쓸',
#   '음'],
#  ['급여',
#   '밀리',
#   '적',
#   '없이',
#   '나오',
#   '고',
#   '강남역',
#   '옆',
#   '어서',
#   '출근',
#   '기',
#   '좋',
#   '음',
#   '팀원',
#   '대부분',
#   '연령',
#   '대',
#   '낮',
#   '크',
#   '게',
#   '세대',
#   '차이',
#   '안',
#   '느껴짐',
#   '업무',
#   '글',
#   '혼자',
#   '다',
#   '해',
#   '볼',
#   '고',
#   '좋',
#   '기획',
#   '면',
#   '직급',
#   '연차',
#   '관계없이',
#   '진행',
#   '가능',
#   '함'],
#  ['젊',
#   '회사',
#   '대',
#   '대',
#   '많',
#   '다',
#   '첫',
#   '회사',
#   '경험',
#   '기',
#   '좋',
#   '편',
#   '고',
#   '신입',
#   '교육',
#   '체계',
#   '적'],
#  ['강남역',
#   '가깝',
#   '고',
#   '위치',
#   '좋',
#   '다',
#   '회사',
#   '발전',
#   '해',
#   '나가',
#   '기',
#   '위해',
#   '대외',
#   '적',
#   '많이',
#   '노력',
#   '한다'],
#  ['연차',
#   '낮',
#   '고',
#   '연령',
#   '대',
#   '낮',
#   '아서',
#   '대부분',
#   '평등',
#   '합니다',
#   '아이디어',
#   '자유',
#   '롭',
#   '게',
#   '낼',
#   '어요'],
#  ['신입',
#   '라도',
#   '배우',
#   '면서',
#   '빠르',
#   '게',
#   '성장',
#   '할',
#   '음',
#   '파트',
#   '장',
#   '이나',
#   '팀장',
#   '승진',
#   '할',
#   '기회',
#   '많',
#   '편',
#   '워라',
#   '밸',
#   '포기',
#   '고',
#   '만',
#   '면서',
#   '버티',
#   '면',
#   '인정받',
#   '음'],
#  ['월급', '제때', '들어온다', '회사', '강남', '기', '때문', '한강', '이남', '사', '사람', '좋', '다'],
#  ['첫',
#   '사회',
#   '시작',
#   '신입',
#   '또래',
#   '많',
#   '아서',
#   '편안',
#   '게',
#   '회사',
#   '생활',
#   '할',
#   '직장',
#   '부서',
#   '갖춰',
#   '어서',
#   '나름',
#   '괜찮',
#   '회사'],
#  ['직원', '대체로', '젊', '고', '회식', '음', '본인', '업무', '만', '면', '칼', '퇴', '가능'],
#  ['모두', '다', '나이', '비슷비슷', '해서', '알', '바', '느낌', '친구', '음'],
#  ['회식',
#   '다',
#   '업무',
#   '빨리',
#   '처리',
#   '다',
#   '니',
#   '손',
#   '빨라진다',
#   '젊',
#   '사원',
#   '많',
#   '신입',
#   '한정',
#   '통한다'],
#  ['장점',
#   '모니터',
#   '듀얼',
#   '기본',
#   '제공',
#   '인',
#   '빼',
#   '고',
#   '아무것',
#   '음',
#   '옷',
#   '막',
#   '입',
#   '고',
#   '다녀도',
#   '아무',
#   '뭐',
#   '라',
#   '안',
#   '한다는',
#   '정도'],
#  ['미혼', '자취생', '한정', '모닝', '밀크', '토스트', '빵', '외', '복지'],
#  ['여러',
#   '가지',
#   '분야',
#   '확장',
#   '인해',
#   '다양',
#   '경험',
#   '쌓',
#   '음',
#   '직원',
#   '간',
#   '분위기',
#   '좋',
#   '음',
#   '점점',
#   '기업',
#   '으로서',
#   '발전',
#   '고',
#   '모습',
#   '음'],
#  ['팀',
#   '동료',
#   '간',
#   '분위기',
#   '편안',
#   '고',
#   '매우',
#   '좋',
#   '음',
#   '업무',
#   '적',
#   '사수',
#   '선임',
#   '알려',
#   '줘서',
#   '빨리',
#   '배울',
#   '었',
#   '으면',
#   '새로운',
#   '업무',
#   '할',
#   '기존',
#   '레퍼런스',
#   '남',
#   '업무',
#   '수월',
#   '함'],
#  ['연차',
#   '윗사람',
#   '눈치',
#   '안',
#   '고',
#   '쓸',
#   '고',
#   '나름',
#   '수평',
#   '적',
#   '인',
#   '분위기',
#   '평균',
#   '적',
#   '연령',
#   '대',
#   '후반',
#   '대',
#   '초반'],
#  ['해',
#   '커스',
#   '직원',
#   '할인',
#   '받',
#   '부분',
#   '음',
#   '강남',
#   '근처',
#   '휴사',
#   '다수',
#   '보유',
#   '팀',
#   '분위기',
#   '화기애애',
#   '했',
#   '음',
#   '시',
#   '신',
#   '퇴근',
#   '아주',
#   '지켜',
#   '편',
#   '알',
#   '바',
#   '만',
#   '그런',
#   '인지',
#   '모르',
#   '겠',
#   '음'],
#  ['장점',
#   '진짜',
#   '하나',
#   '는데',
#   '뭘',
#   '적',
#   '어야',
#   '할지',
#   '모르',
#   '겠',
#   '음',
#   '적',
#   '연봉',
#   '야근',
#   '수당',
#   '고',
#   '주말',
#   '근무',
#   '고',
#   '식대',
#   '안',
#   '나옴',
#   '위',
#   '시키',
#   '대로',
#   '무조건',
#   '해야',
#   '구조',
#   '라',
#   '창의',
#   '적',
#   '인',
#   '못',
#   '함',
#   '옛날',
#   '방식',
#   '고집',
#   '해서',
#   '쌓이',
#   '포트폴리오',
#   '촌',
#   '스러움',
#   '냉장고',
#   '청소',
#   '청소',
#   '담당자',
#   '아닌',
#   '직원',
#   '한테',
#   '돌려서',
#   '게',
#   '함',
#   '뭐',
#   '을까',
#   '장점',
#   '강남역',
#   '인',
#   '거',
#   '거리',
#   '가깝',
#   '다'],
#  ['분위기',
#   '좋',
#   '고',
#   '다양',
#   '직무',
#   '대한',
#   '이해도',
#   '높',
#   '질',
#   '음',
#   '성과',
#   '좋',
#   '다면',
#   '승진',
#   '기회',
#   '많',
#   '음'],
#  ['수평',
#   '적',
#   '인',
#   '분위기',
#   '좋',
#   '사람',
#   '많',
#   '음',
#   '신입',
#   '다양',
#   '상위',
#   '업무',
#   '빠르',
#   '게',
#   '배울',
#   '음',
#   '눈치',
#   '고',
#   '연차',
#   '사용',
#   '가능'],
#  ['연차',
#   '눈치',
#   '안',
#   '고',
#   '쓸',
#   '업무',
#   '강도',
#   '낮',
#   '편',
#   '라',
#   '스트레스',
#   '안',
#   '받',
#   '고',
#   '고',
#   '싶',
#   '으신',
#   '분',
#   '추천',
#   '드려요',
#   '야근',
#   '음'],
#  ['연차',
#   '눈치',
#   '안',
#   '고',
#   '사용',
#   '가능',
#   '인턴',
#   '정',
#   '직원',
#   '만큼',
#   '할',
#   '음',
#   '경험',
#   '쌓',
#   '기',
#   '좋',
#   '음',
#   '제휴',
#   '맺',
#   '곳',
#   '많',
#   '아서',
#   '점심',
#   '할인',
#   '가능',
#   '비',
#   '쌈',
#   '강남역',
#   '가까움',
#   '꼰대',
#   '음',
#   '젊',
#   '분위기',
#   '인트라넷',
#   '고',
#   '배울',
#   '음'],
#  ['기업', '장점', '진짜', '해', '커스', '강', '개', '무료', '다는', '게', '그나마', '장점', '임'],
#  ['미혼', '자취생', '주어지', '우유', '모닝', '빵', '잼', '제공', '정도', '라고', '생각', '합니다'],
#  ['이름', '면', '대', '안다', '강남역', '번', '출구', '엄청', '가깝', '진', '가까움'],
#  ['회사',
#   '멈춰',
#   '고',
#   '계속',
#   '해서',
#   '발전함',
#   '직장',
#   '동료',
#   '수평',
#   '적',
#   '인',
#   '관계',
#   '임',
#   '아이디어',
#   '자유',
#   '롭',
#   '게',
#   '낼',
#   '음',
#   '휴무',
#   '사용',
#   '크',
#   '게',
#   '제약',
#   '음',
#   '휴양소',
#   '지원',
#   '매우',
#   '좋',
#   '음'],
#  ['다양', '의견', '존중', '수평', '적', '분위기', '젊', '문화', '능력', '발휘', '가능'],
#  ['버티',
#   '고',
#   '나온다면',
#   '워낙',
#   '빡센',
#   '회사',
#   '라',
#   '곳',
#   '버틴',
#   '끈',
#   '기력',
#   '정도',
#   '알',
#   '준다',
#   '함',
#   '외',
#   '장점',
#   '비교',
#   '적',
#   '나이',
#   '대',
#   '어리',
#   '기',
#   '때문',
#   '연차',
#   '반차',
#   '정도',
#   '눈치',
#   '안',
#   '고',
#   '쓸',
#   '음',
#   '우유',
#   '신청',
#   '면',
#   '개정',
#   '눈치',
#   '안',
#   '고',
#   '마심',
#   '아무',
#   '청소',
#   '토스',
#   '트기',
#   '빵',
#   '구워서',
#   '먹',
#   '음'],
#  ['업무', '어렵', '고', '나름', '괜찮', '역세', '권', '라', '괜찮'],
#  ['팀', '정시', '퇴근', '가능', '정도', '그나마', '팀원', '좋', '음'],
#  ['해', '커스', '강의', '제공', '최', '신판', '아님', '강남', '음', '개인주의'],
#  ['신입', '면', '좋', '회사', '컨', '펌', '라인', '많', '아서', '기본기', '다지기', '좋', '회사'],
#  ['고', '싶', '다면', '교육', '카테고리', '든', '해', '볼', '기회', '곳'],
#  ['아침',
#   '마다',
#   '우유',
#   '줌',
#   '기획',
#   '팀',
#   '보조',
#   '팀',
#   '탈퇴',
#   '함',
#   '기획',
#   '팀',
#   '야근',
#   '많',
#   '음'],
#  ['제일',
#   '좋',
#   '점',
#   '모든',
#   '문서',
#   '보드',
#   '화',
#   '신입',
#   '사원',
#   '배우',
#   '기',
#   '그만한',
#   '매뉴얼',
#   '다',
#   '댓글',
#   '커뮤니케이션',
#   '스토리',
#   '쌓',
#   '기',
#   '좋',
#   '고',
#   '사회',
#   '초년생',
#   '적응',
#   '기',
#   '면',
#   '승진',
#   '기회',
#   '좋',
#   '다',
#   '라인',
#   '타',
#   '면',
#   '복지',
#   '라고',
#   '면',
#   '아침',
#   '빵',
#   '이랑',
#   '우유',
#   '먹',
#   '거',
#   '회원',
#   '콘',
#   '사용'],
#  ['인센티브', '여서', '가르치', '만큼', '급여', '받', '학생', '줄', '면', '급여', '줄어듭니다'],
#  ['강남역',
#   '비교',
#   '적',
#   '가까이',
#   '위치',
#   '교통',
#   '편리',
#   '합니다',
#   '청소',
#   '아주머니',
#   '자주',
#   '청소',
#   '해',
#   '줘',
#   '깔끔',
#   '합니다'],
#  ['업무', '수록', '부서', '내', '직원', '끈끈', '해짐', '대', '많', '음'],
#  ['네이밍', '이름', '만', '들어도', '회사', '인지', '많', '사람', '안다'],
#  ['연차',
#   '케',
#   '바케',
#   '으나',
#   '적어도',
#   '꼰대',
#   '음',
#   '대체로',
#   '편하',
#   '게',
#   '사용',
#   '가능',
#   '젊',
#   '분위기',
#   '꼰대',
#   '음'],
#  ['회사', '직장', '동료', '매우', '좋', '고', '간섭', '분위기', '라', '좋'],
#  ['강남역',
#   '근처',
#   '위치',
#   '해',
#   '교통',
#   '편리',
#   '다',
#   '밖',
#   '새로',
#   '건물',
#   '신축',
#   '될',
#   '예정',
#   '깨끗',
#   '고',
#   '넓',
#   '곳',
#   '할',
#   '다',
#   '편의',
#   '시설',
#   '들어올',
#   '예정',
#   '라는',
#   '얘기',
#   '음'],
#  ['아닌',
#   '걸',
#   '알',
#   '면서',
#   '업계',
#   '위',
#   '라서',
#   '퇴사',
#   '못',
#   '함',
#   '아닌',
#   '걸',
#   '알',
#   '면서',
#   '남',
#   '해줘서',
#   '못',
#   '관',
#   '둠'],
#  ['이름값',
#   '명성',
#   '고',
#   '장점',
#   '회사',
#   '번화가',
#   '주변',
#   '라',
#   '점심',
#   '먹',
#   '고',
#   '싶',
#   '걸',
#   '먹',
#   '다',
#   '정도'],
#  ['수평',
#   '적',
#   '인',
#   '분위기',
#   '팀',
#   '마다',
#   '다르',
#   '다',
#   '내',
#   '던',
#   '팀',
#   '인턴',
#   '칼',
#   '퇴',
#   '였',
#   '다',
#   '자신',
#   '의지',
#   '남',
#   '음',
#   '팀장',
#   '님',
#   '피드백',
#   '상세',
#   '고',
#   '좋',
#   '았',
#   '음'],
#  ['월급', '제때', '들어와요', '눈치', '안', '고', '편해요', '할', '만', '제대로', '면', '돼요'],
#  ['조직',
#   '젊',
#   '어서',
#   '비슷',
#   '또래',
#   '사람',
#   '할',
#   '다',
#   '야근',
#   '택시',
#   '비',
#   '지원',
#   '처음',
#   '끝',
#   '혼자',
#   '할',
#   '다'],
#  ['재정', '기반', '튼튼', '해', '월급', '제때', '나온다', '강남역', '근처', '라', '교통', '편리', '다'],
#  ['이름값',
#   '주변',
#   '다닌다고',
#   '면',
#   '모르',
#   '사람',
#   '좋',
#   '회사',
#   '인',
#   '줄',
#   '안다',
#   '근무지',
#   '강남역',
#   '인근',
#   '스펙',
#   '이런',
#   '거',
#   '필요',
#   '없이',
#   '아무',
#   '들어올',
#   '다'],
#  ['퇴사',
#   '처리',
#   '굉장',
#   '신속',
#   '일사천리',
#   '직원',
#   '착함',
#   '성격',
#   '조금',
#   '라도',
#   '사람',
#   '다',
#   '때려치운',
#   '듯',
#   '인지',
#   '망하',
#   '업종'],
#  ['승진',
#   '빠르',
#   '다는',
#   '외',
#   '음',
#   '사람',
#   '많이',
#   '나가',
#   '다',
#   '니',
#   '승진',
#   '기회',
#   '많이',
#   '주어짐'],
#  ['월급', '맞춰서', '나옵니다', '나름', '작', '복지', '긴', '는데', '복지', '라고', '했'],
#  ['수평',
#   '적',
#   '인',
#   '조직',
#   '문화',
#   '자유',
#   '로운',
#   '회사',
#   '분위기',
#   '연령',
#   '대',
#   '낮',
#   '젊',
#   '기업'],
#  ['인터넷',
#   '강의',
#   '수강',
#   '가능',
#   '리조트',
#   '이용',
#   '만',
#   '원',
#   '선',
#   '가능',
#   '함',
#   '강남역',
#   '출출히',
#   '랑',
#   '가까움',
#   '주변',
#   '맛집',
#   '많',
#   '음'],
#  ['빵', '먹', '음', '직원', '연령층', '대임', '직원', '끼리', '분위기', '좋', '음'],
#  ['야근',
#   '택시',
#   '비',
#   '지원',
#   '많',
#   '다',
#   '니',
#   '다',
#   '자기',
#   '느라',
#   '바빠서',
#   '인간',
#   '관계',
#   '스트레스',
#   '적',
#   '편'],
#  ['해', '커스', '교육', '그룹', '중', '어학', '만', '무료', '다', '외', '엔', '전혀', '다'],
#  ['교육',
#   '그룹',
#   '중',
#   '가장',
#   '큰',
#   '회사',
#   '라는',
#   '장점',
#   '라면',
#   '장점',
#   '입니다',
#   '회식',
#   '강요',
#   '거나',
#   '많',
#   '점',
#   '장점',
#   '입니다'],
#  ['젊',
#   '나이',
#   '대',
#   '직원',
#   '많',
#   '아서',
#   '편하',
#   '게',
#   '얘기',
#   '할',
#   '장점',
#   '었',
#   '불만',
#   '라든지',
#   '고충',
#   '건',
#   '터놓',
#   '고',
#   '얘기',
#   '해서',
#   '좋',
#   '았'],
#  ['연차',
#   '윗사람',
#   '눈치',
#   '없이',
#   '자유자재',
#   '쓸',
#   '어서',
#   '좋',
#   '고',
#   '자유',
#   '로운',
#   '분위기',
#   '다'],
#  ['교육',
#   '기업',
#   '답',
#   '게',
#   '직원',
#   '교육',
#   '동영상',
#   '무료',
#   '볼',
#   '음',
#   '모든',
#   '강의',
#   '고',
#   '오래',
#   '된',
#   '강의',
#   '만',
#   '가능'],
#  ['명절', '마다', '만', '원', '배', '박스', '보내', '줌', '해', '커스', '교육', '인', '강', '무료'],
#  ['괜찮',
#   '아요',
#   '연차',
#   '연봉',
#   '좋',
#   '고',
#   '자유',
#   '로워요',
#   '자기',
#   '할',
#   '제대로',
#   '고',
#   '똒바로',
#   '해야',
#   '나머지',
#   '별다른',
#   '터치',
#   '음',
#   '디'],
#  ['연차', '사용', '가능', '업무', '관련', '배울', '음', '주변', '음식점', '많', '음'],
#  ['해',
#   '커스',
#   '제작',
#   '동영상',
#   '강의',
#   '복지',
#   '차원',
#   '지급',
#   '해준다',
#   '토익',
#   '점수',
#   '높여',
#   '취업',
#   '데',
#   '도움',
#   '었',
#   '다',
#   '어서',
#   '인지',
#   '구성원',
#   '간',
#   '분위기',
#   '좋',
#   '다'],
#  ['연차',
#   '눈치',
#   '안',
#   '고',
#   '쓸',
#   '편',
#   '다',
#   '오래',
#   '된',
#   '강의',
#   '기본',
#   '적',
#   '인',
#   '온라인',
#   '강의',
#   '제공',
#   '된다'],
#  ['야근', '많', '아서', '늦', '게', '퇴근', '해서', '아침', '늦', '게', '출근', '할', '다'],
#  ['수평', '적', '인', '사무실', '분위기', '직급', '나누', '으려고', '함'],
#  ['연차',
#   '눈치',
#   '안',
#   '고',
#   '쓸',
#   '으면',
#   '할',
#   '만',
#   '빠르',
#   '게',
#   '끝내',
#   '면',
#   '칼',
#   '퇴',
#   '가능',
#   '많',
#   '아서',
#   '하루하루',
#   '정신없',
#   '음'],
#  ['자유', '로운', '연차', '사용', '자유', '로운', '업무', '분위기', '수평', '적', '인', '조직', '구조'],
#  ['수평',
#   '적',
#   '인',
#   '업무',
#   '형태',
#   '마음',
#   '었',
#   '으며',
#   '자유',
#   '롭',
#   '게',
#   '자신',
#   '의견',
#   '피력',
#   '주도',
#   '적',
#   '처리',
#   '할',
#   '다는',
#   '매력',
#   '다',
#   '자신',
#   '열심',
#   '빠른',
#   '승진',
#   '역시',
#   '가능',
#   '할',
#   '듯'],
#  ['강남역',
#   '어서',
#   '퇴근',
#   '고',
#   '술',
#   '먹',
#   '으러',
#   '기',
#   '편하',
#   '다',
#   '착하',
#   '고',
#   '어린',
#   '친구',
#   '자주',
#   '퇴사',
#   '해서',
#   '뜻밖에',
#   '인맥',
#   '넓',
#   '진다',
#   '해',
#   '커스',
#   '욕',
#   '면서',
#   '친해',
#   '고',
#   '다',
#   '퇴사',
#   '고',
#   '모여도',
#   '해',
#   '커스',
#   '욕',
#   '면서',
#   '언제나',
#   '즐겁',
#   '다'],
#  ['음', '공무원', '처럼', '튀', '사람', '에겐', '나쁘', '낳', '음'],
#  ['승진', '빠름', '해', '커스', '강의', '모두', '무료', '가능', '회사', '위치', '강남'],
#  ['사람', '많이', '들어와서', '새', '사람', '많이', '어서', '생기', '다'],
#  ['회식', '고', '그나마', '자유', '로운', '분위기', '강남역', '가깝', '다'],
#  ['강남역', '근처', '만', '해도', '분위기', '회식', '음'],
#  ['흠', '열심', '공부', '할', '느낌', '든다'],
#  ['근무', '어서', '상사', '눈치', '별로', '으며', '자기', '맡', '스스로', '진행', '기', '좋', '다'],
#  ['안',
#   '전한',
#   '곳',
#   '나름',
#   '업계',
#   '큰',
#   '곳',
#   '기본',
#   '적',
#   '근무',
#   '환경',
#   '나쁘',
#   '다',
#   '회사',
#   '접근성',
#   '좋',
#   '위치',
#   '교통',
#   '편리',
#   '다'],
#  ['주로',
#   '대로',
#   '수평',
#   '적',
#   '인',
#   '기업',
#   '문화',
#   '복장',
#   '자유',
#   '로운',
#   '편',
#   '회식',
#   '음',
#   '인턴',
#   '아르바이트',
#   '생',
#   '야근',
#   '음'],
#  ['젊',
#   '분위기',
#   '라서',
#   '동기',
#   '선배',
#   '친하',
#   '게',
#   '지낼',
#   '는데',
#   '이것',
#   '케밥',
#   '케',
#   '인',
#   '음',
#   '팀',
#   '사람',
#   '다',
#   '좋',
#   '았',
#   '는데',
#   '팀',
#   '젊',
#   '꼰대',
#   '텃세',
#   '었',
#   '다고',
#   '니',
#   '뭐',
#   '강남역',
#   '가까운',
#   '지리',
#   '적',
#   '이점',
#   '정도'],
#  ['업무',
#   '매뉴얼',
#   '상세',
#   '다',
#   '직원',
#   '교육',
#   '편',
#   '능력',
#   '만',
#   '녀',
#   '승진',
#   '가능',
#   '서울',
#   '출퇴근',
#   '게',
#   '단점',
#   '면',
#   '장점'],
#  ['다양', '업무', '해', '볼', '회사', '내', '업무', '아닌', '할', '점', '주의'],
#  ['연차',
#   '쓸',
#   '음',
#   '야근',
#   '식대',
#   '간',
#   '식비',
#   '음',
#   '그거',
#   '안',
#   '받',
#   '고',
#   '야근',
#   '안',
#   '고',
#   '싶',
#   '다'],
#  ['끊임없이',
#   '업무',
#   '시키',
#   '기',
#   '짧',
#   '시기',
#   '많',
#   '해낼',
#   '으면',
#   '어쩔',
#   '없이',
#   '해내',
#   '게',
#   '됨'],
#  ['좋',
#   '점',
#   '신입',
#   '임',
#   '사이트',
#   '운영',
#   '할',
#   '기회',
#   '많',
#   '권한',
#   '주어짐',
#   '주체',
#   '적',
#   '작업',
#   '진행할',
#   '음'],
#  ['젊',
#   '기업',
#   '어서',
#   '분위기',
#   '자유',
#   '롭',
#   '다',
#   '열심',
#   '고',
#   '욕심',
#   '만',
#   '으면',
#   '그만큼',
#   '승진',
#   '빠르',
#   '다'],
#  ['나름', '편하', '다', '앉', '아서', '기', '땜', '아르바이트', '중', '좋', '다', '추천', '합니다'],
#  ['토스트', '기계', '최소', '인데', '장점', '다'],
#  ['비슷', '나이', '대', '동료', '서로', '고생', '며', '친해질', '다', '밖', '만날', '정도', '친해진다'],
#  ['연차',
#   '자유',
#   '롭',
#   '게',
#   '쓸',
#   '음',
#   '전체',
#   '적',
#   '연령',
#   '대',
#   '낮',
#   '편한',
#   '분위기',
#   '임',
#   '기업',
#   '이름',
#   '고',
#   '장점',
#   '음'],
#  ['또래',
#   '직장',
#   '동료',
#   '많',
#   '팀',
#   '분위기',
#   '좋',
#   '고',
#   '어울리',
#   '기',
#   '쉽',
#   '다',
#   '이것',
#   '팀장',
#   '바이',
#   '팀장',
#   '하도',
#   '많이',
#   '금방',
#   '나가',
#   '서',
#   '어지간',
#   '버티',
#   '면',
#   '젊',
#   '나이',
#   '경력',
#   '달',
#   '음'],
#  ['교육',
#   '업계',
#   '위',
#   '라는',
#   '자부심',
#   '존재',
#   '앞',
#   '사업',
#   '확장',
#   '기대',
#   '됨',
#   '다양',
#   '복지',
#   '노력'],
#  ['기업', '장점', '라고', '할', '게', '었', '회사', '라', '학원', '배우', '러', '느낌'],
#  ['회사',
#   '명과',
#   '브랜드',
#   '국내',
#   '인지도',
#   '매우',
#   '높',
#   '아서',
#   '재직',
#   '중',
#   '주변',
#   '사람',
#   '한테',
#   '선망',
#   '눈길',
#   '받',
#   '았',
#   '고',
#   '이직',
#   '할',
#   '도움',
#   '됨'],
#  ['강남역', '주변', '위치', '다는', '가장', '큰', '장점', '입니다'],
#  ['위치', '좋', '운', '좋', '으면', '친구', '동료', '사귈', '다'],
#  ['물', '경력', '업도', '서', '이력', '쓰', '기', '좋', '브랜드', '네임', '밸류'],
#  ['연차',
#   '첫',
#   '달',
#   '눈치',
#   '없이',
#   '쓸',
#   '좋',
#   '았',
#   '다',
#   '첫',
#   '달',
#   '눈치',
#   '안',
#   '고',
#   '씀',
#   '월급',
#   '번',
#   '밀리',
#   '고',
# ...
#   '강',
#   '듣',
#   '게',
#   '해준다',
#   '회식',
#   '안',
#   '해서',
#   '좋',
#   '음',
#   '교육',
#   '업계',
#   '에선',
#   '꽤',
#   '큰',
#   '규모',
#   '네이밍',
#   '젊',
#   '직원',
#   '사람',
#   '매우',
#   '좋',
#   '다'],
#  ['나이',
#   '어린',
#   '친구',
#   '많',
#   '또래',
#   '끼리',
#   '할',
#   '음',
#   '디자이너',
#   '워낙',
#   '많',
#   '육아',
#   '휴직',
#   '쓰',
#   '고',
#   '와도',
#   '티오',
#   '항상',
#   '듯'],
#  ['식빵', '쨈', '쓸', '음', '아무리', '생각', '해도', '장점', '음'],
#  ['장점', '뭐', '듀얼', '모니터', '진짜', '장점', '어요'],
#  ['수평',
#   '적',
#   '인',
#   '구조',
#   '조용',
#   '분위기',
#   '라',
#   '자기',
#   '업무',
#   '만',
#   '면',
#   '됨',
#   '회식',
#   '음'],
#  ['업무',
#   '분담',
#   '확실',
#   '함',
#   '이름',
#   '만',
#   '들어도',
#   '알',
#   '만',
#   '기업',
#   '가치',
#   '음',
#   '막상',
#   '들어가',
#   '서',
#   '다',
#   '면',
#   '별다른',
#   '고',
#   '대',
#   '기업',
#   '못',
#   '미치',
#   '듯',
#   '경영',
#   '체계'],
#  ['업무',
#   '체계',
#   '확실',
#   '고',
#   '월급',
#   '추가',
#   '근무',
#   '꼬박꼬박',
#   '들어왔',
#   '다',
#   '칼',
#   '퇴',
#   '해도',
#   '상관없',
#   '었',
#   '다'],
#  ['회사',
#   '내',
#   '서대',
#   '육아',
#   '휴직',
#   '회사',
#   '제휴',
#   '리조트',
#   '저렴',
#   '게',
#   '이용',
#   '가능',
#   '토스트',
#   '전화',
#   '받',
#   '음',
#   '팀',
#   '제외',
#   '너무',
#   '바빠서',
#   '던',
#   '전우애',
#   '생김'],
#  ['기업',
#   '이미지',
#   '친숙',
#   '고',
#   '보다',
#   '젊',
#   '사람',
#   '많',
#   '기',
#   '때문',
#   '기업',
#   '문화',
#   '활기찬',
#   '면',
#   '다'],
#  ['신입',
#   '다양',
#   '업무',
#   '맡',
#   '아기',
#   '많',
#   '경험',
#   '할',
#   '었',
#   '고',
#   '적응',
#   '면',
#   '서든',
#   '적응',
#   '할',
#   '음'],
#  ['팀', '다르', '겠', '야근', '매우', '강요', '한다거나', '분위기', '약함'],
#  ['글쎄요', '사람', '젊', '고', '개인주의', '성향', '강해서', '서로', '터치', '심하', '아요'],
#  ['연령층',
#   '젊',
#   '어서',
#   '팀원',
#   '만나',
#   '면',
#   '즐겁',
#   '게',
#   '할',
#   '음',
#   '젊',
#   '어서',
#   '승진',
#   '빠를',
#   '음',
#   '팀',
#   '연차',
#   '팀장',
#   '기',
#   '함'],
#  ['일부', '인정받', '극소수', '직원', '파격', '적', '인', '혜택', '듯', '함'],
#  ['학원', '강의', '무료', '듣', '는다', '식빵', '준다', '강남', '라는', '위치'],
#  ['수평', '적', '기', '만', '부서', '별', '분위기', '차이', '큼', '편리', '교통', '이용', '가능'],
#  ['대체',
#   '적',
#   '연령',
#   '대',
#   '높',
#   '편',
#   '접근성',
#   '좋',
#   '고',
#   '아무래도',
#   '강남',
#   '라',
#   '그런지',
#   '이런',
#   '저런',
#   '인프라',
#   '좋',
#   '음'],
#  ['직원', '대부분', '어려서', '동아리', '느낌', '요', '스스로', '뭔가', '할', '어요'],
#  ['본사', '직원', '복지', '자사', '강의', '수강', '가능', '근데', '가능', '새벽', '야근', '후'],
#  ['했',
#   '던',
#   '동기',
#   '좋',
#   '았',
#   '다',
#   '아직',
#   '연락',
#   '고',
#   '지낸다',
#   '네임',
#   '드가',
#   '다가',
#   '구',
#   '여실',
#   '깨달',
#   '았',
#   '다'],
#  ['안정',
#   '적',
#   '인',
#   '회사',
#   '월급',
#   '밀리',
#   '고',
#   '좋',
#   '다',
#   '영어',
#   '할인',
#   '받',
#   '아서',
#   '공부',
#   '할',
#   '다',
#   '여자',
#   '다니',
#   '기',
#   '좋',
#   '다'],
#  ['아무리', '생각', '고', '생각', '고', '생각', '해도', '음', '장점', '회사'],
#  ['이름값',
#   '주변',
#   '상가',
#   '할인',
#   '쉬',
#   '시간',
#   '자유',
#   '로움',
#   '다양',
#   '팀',
#   '존재',
#   '해서',
#   '경험',
#   '면',
#   '라도',
#   '연차',
#   '사용',
#   '자유',
#   '로움',
#   '사람',
#   '좋',
#   '다',
#   '월급날',
#   '아침',
#   '일찍',
#   '입금',
#   '됨'],
#  ['해',
#   '커스',
#   '라는',
#   '이름',
#   '알려져',
#   '부서',
#   '사람',
#   '괜찮',
#   '편',
#   '었',
#   '다',
#   '나가',
#   '게',
#   '는데'],
#  ['교통', '좋', '다는', '모르', '겠', '음', '강의', '무료', '다는'],
#  ['부바',
#   '부리',
#   '연차',
#   '눈치',
#   '안',
#   '고',
#   '쓸',
#   '음',
#   '팀원',
#   '사람',
#   '때문',
#   '다님',
#   '월급',
#   '정시',
#   '입금',
#   '강남역',
#   '가까움'],
#  ['연차',
#   '눈치',
#   '안',
#   '보이',
#   '편',
#   '야근',
#   '시',
#   '간식',
#   '비랑',
#   '택시',
#   '비',
#   '나옴',
#   '젊',
#   '세대',
#   '많',
#   '아서',
#   '좋',
#   '사람',
#   '만날',
#   '음'],
#  ['빠른',
#   '승진',
#   '할',
#   '음',
#   '자취생',
#   '아침',
#   '우유',
#   '제공',
#   '됨',
#   '강남역',
#   '근처',
#   '제휴',
#   '가게',
#   '많',
#   '보다',
#   '저렴',
#   '금액',
#   '물건',
#   '음식',
#   '결제',
#   '할',
#   '음'],
#  ['여러', '가지', '경험', '해', '볼', '다는', '장점', '아닌', '장점', '포트폴리오', '쌓', '다'],
#  ['젊', '사람', '많', '다는', '점', '자유', '롭', '게', '의견', '할', '다는', '점'],
#  ['팀',
#   '내',
#   '분위기',
#   '적응',
#   '면',
#   '재미',
#   '음',
#   '대체',
#   '적',
#   '연령',
#   '대',
#   '대',
#   '중반',
#   '겉돌',
#   '며',
#   '여초',
#   '텃세',
#   '편'],
#  ['야근', '면', '날', '늦', '게', '출근', '해도', '된다는', '게', '제일', '큰', '장점', '었', '음'],
#  ['교육',
#   '그룹',
#   '중',
#   '네임',
#   '밸류',
#   '조금',
#   '어서',
#   '괜찮',
#   '거',
#   '그만큼',
#   '업무',
#   '많',
#   '듯',
#   '느낌',
#   '었',
#   '음',
#   '여려',
#   '가지',
#   '명목상',
#   '복지',
#   '기본',
#   '적',
#   '듯',
#   '다'],
#  ['업무',
#   '강도',
#   '높',
#   '편',
#   '그만큼',
#   '경력',
#   '경험',
#   '할',
#   '다',
#   '교육',
#   '업계',
#   '전반',
#   '적',
#   '인',
#   '업무',
#   '배울',
#   '다'],
#  ['교육',
#   '업계',
#   '위라',
#   '나름',
#   '대로',
#   '프라이드',
#   '가질',
#   '만',
#   '함',
#   '서',
#   '해',
#   '커스',
#   '다닌다고',
#   '면',
#   '해줌'],
#  ['연령',
#   '대',
#   '젊',
#   '다',
#   '사무실',
#   '분위기',
#   '좋',
#   '음',
#   '개인',
#   '별',
#   '법인',
#   '카드',
#   '사용',
#   '가능'],
#  ['비슷',
#   '연령',
#   '대',
#   '직원',
#   '많',
#   '대학',
#   '생활',
#   '연장',
#   '처럼',
#   '재미난',
#   '직장',
#   '생활',
#   '가능',
#   '다',
#   '조용',
#   '분위기',
#   '회사',
#   '아닌',
#   '활동',
#   '적',
#   '인',
#   '분위기',
#   '다',
#   '의외',
#   '업무',
#   '프로세스',
#   '많이',
#   '갖춰져',
#   '다'],
#  ['강남역',
#   '라',
#   '주변',
#   '인프라',
#   '좋',
#   '음',
#   '그게',
#   '끝',
#   '연차',
#   '나왔',
#   '는데',
#   '다',
#   '축하',
#   '한다고'],
#  ['체계',
#   '적',
#   '인',
#   '시스템',
#   '갖춰져',
#   '업무',
#   '기',
#   '편리',
#   '합니다',
#   '분야',
#   '별',
#   '나눠져',
#   '회사',
#   '돌아가',
#   '전반',
#   '적',
#   '인',
#   '배울'],
#  ['위',
#   '라는',
#   '네임',
#   '밸류',
#   '자부심',
#   '음',
#   '교육',
#   '적',
#   '인',
#   '목적',
#   '한다는',
#   '대한',
#   '뿌듯',
#   '함',
#   '교육',
#   '적',
#   '인',
#   '대한',
#   '복지',
#   '혜택',
#   '음',
#   '인터넷',
#   '강의',
#   '라던가',
#   '교재',
#   '할',
#   '인'],
#  ['연차', '자유', '롭', '게', '사용', '가능', '빵', '이랑', '우유', '매일', '아침', '제공', '됨'],
#  ['일단',
#   '브랜드',
#   '인지도',
#   '굉장',
#   '좋',
#   '은데',
#   '진',
#   '입장',
#   '벽',
#   '엄청나',
#   '게',
#   '높',
#   '든',
#   '듯'],
#  ['교육', '계', '이름', '곳', '교육', '업계', '시스템', '배울', '곳'],
#  ['많', '보람', '느낄', '많', '아서', '많이', '배울', '업무', '입니다', '직무', '다릅니다'],
#  ['항상',
#   '많',
#   '배우',
#   '기',
#   '좋',
#   '환경',
#   '기업',
#   '문화',
#   '만들',
#   '기',
#   '위해',
#   '노력',
#   '며',
#   '직원',
#   '업무',
#   '능력',
#   '향상',
#   '위해',
#   '다양',
#   '교육',
#   '실시',
#   '함'],
#  ['월급',
#   '제때',
#   '나온다',
#   '업무',
#   '프로세스',
#   '효율',
#   '적',
#   '다',
#   '나름',
#   '수평',
#   '적',
#   '인',
#   '근무',
#   '환경',
#   '젊',
#   '분위기',
#   '회사',
#   '일반',
#   '회사',
#   '보다',
#   '개개인',
#   '존중',
#   '함',
#   '회식',
#   '음'],
#  ['식빵', '잼', '무한', '제공', '이것', '밖에', '고', '복지', '제로', '가깝'],
#  ['강남', '주변', '맛', '집', '이나', '볼거리', '많', '교통', '좋', '아요'],
#  ['브랜드', '마케팅', '할', '기회', '주어짐', '교육', '절차', '나름', '체계', '적', '임'],
#  ['교육',
#   '업계',
#   '전반',
#   '적',
#   '인',
#   '업무',
#   '경험',
#   '할',
#   '음',
#   '수평',
#   '적',
#   '사내',
#   '분위기',
#   '젊',
#   '회사',
#   '분위기'],
#  ['젊',
#   '기업',
#   '문화',
#   '가지',
#   '고',
#   '흔',
#   '꼰대',
#   '고',
#   '사내정치',
#   '이런',
#   '게',
#   '음',
#   '사업',
#   '군',
#   '많',
#   '고',
#   '회사',
#   '내',
#   '기획',
#   '개발자',
#   '디자이너',
#   '영상',
#   '편집자',
#   '다',
#   '업무',
#   '할',
#   '여러',
#   '가지',
#   '배울',
#   '고',
#   '다양',
#   '업무',
#   '경험',
#   '할',
#   '음'],
#  ['디자인',
#   '적',
#   '배울',
#   '게',
#   '많',
#   '고',
#   '손',
#   '빨라질',
#   '으며',
#   '사업',
#   '군',
#   '다양',
#   '만큼',
#   '다양',
#   '디자인',
#   '요구',
#   '많',
#   '경험',
#   '할',
#   '다'],
#  ['인강', '수업', '어서', '좋', '그다지', '많', '장점', '갖', '고', '는지', '모르', '겠', '회사'],
#  ['대외', '적', '기업', '명', '인지도', '다는', '점', '강남', '위치', '해서', '출퇴근', '편합니다'],
#  ['연봉', '나쁘', '다', '동기', '이랑', '친해', '면', '서로', '된다'],
#  ['전공', '연관', '없이', '새로운', '도전', '가능', '업무', '관련', '다양', '경험', '쌓', '음'],
#  ['이나',
#   '연차',
#   '능력',
#   '상관없이',
#   '기회',
#   '만',
#   '다면',
#   '든',
#   '팀장',
#   '라는',
#   '이름',
#   '달',
#   '고',
#   '할',
#   '회사',
#   '임',
#   '그만큼',
#   '팀장',
#   '자리',
#   '어렵',
#   '고',
#   '시키',
#   '면',
#   '할',
#   '음'],
#  ['외국어',
#   '교육',
#   '관심',
#   '고',
#   '좋',
#   '해당',
#   '분야',
#   '곳',
#   '보다',
#   '빠르',
#   '게',
#   '습득',
#   '가능',
#   '업무',
#   '관련',
#   '해',
#   '다양',
#   '분야',
#   '사람',
#   '만나',
#   '며',
#   '네트워크',
#   '넓',
#   '음',
#   '직장',
#   '내',
#   '대인',
#   '관계',
#   '스트레스',
#   '적',
#   '편'],
#  ['팀',
#   '다',
#   '팀',
#   '능력',
#   '빠르',
#   '게',
#   '승진',
#   '함',
#   '복장',
#   '자유',
#   '롭',
#   '고',
#   '동료',
#   '직원',
#   '간',
#   '수평',
#   '적',
#   '고',
#   '친함',
#   '젊',
#   '직원',
#   '많',
#   '고',
#   '감각',
#   '적',
#   '인',
#   '기획력',
#   '키울',
#   '음',
#   '직원',
#   '복지',
#   '전문',
#   '온',
#   '오프',
#   '강의',
#   '수강',
#   '가능',
#   '함'],
#  ['해',
#   '커스',
#   '인지',
#   '덕분',
#   '가질',
#   '장점',
#   '회사',
#   '위치',
#   '정말',
#   '좋',
#   '다고',
#   '생각',
#   '함',
#   '온라인',
#   '바이럴',
#   '마케팅',
#   '단기간',
#   '속성',
#   '교육',
#   '받',
#   '었',
#   '다는',
#   '생각',
#   '듦'],
#  ['많', '학생', '다니', '학원', '라', '인지', '높', '음', '사람', '젊음'],
#  ['출퇴근',
#   '시간',
#   '플렉서블',
#   '함',
#   '업무',
#   '중심',
#   '평가',
#   '고',
#   '움직임',
#   '눈치',
#   '볼일',
#   '음',
#   '젊',
#   '고',
#   '수평',
#   '적',
#   '인',
#   '문화'],
#  ['강', '높', '업무', '멘', '틀', '강해져서', '직후', '감사', '면', '직장', '생활', '할', '음'],
#  ['젊',
#   '사람',
#   '많',
#   '고',
#   '강남',
#   '위치',
#   '함',
#   '연차',
#   '오래',
#   '면',
#   '여름휴가',
#   '길',
#   '짐',
#   '여름휴가',
#   '고',
#   '맘대로',
#   '못',
#   '씀',
#   '연차',
#   '세상',
#   '쓴맛',
#   '빠르',
#   '게',
#   '배울',
#   '음',
#   '성격',
#   '급',
#   '해짐',
#   '회사',
#   '다니',
#   '다',
#   '회사',
#   '면',
#   '빨리',
#   '한다고',
#   '좋아함'],
#  ['사내',
#   '커뮤니케이션',
#   '시스템',
#   '발전',
#   '다',
#   '정보',
#   '저장',
#   '전달',
#   '방식',
#   '매우',
#   '발전',
#   '다',
#   '인수인계',
#   '받',
#   '기',
#   '수월',
#   '고',
#   '팀',
#   '프로젝트',
#   '기',
#   '용이',
#   '문화',
#   '다',
#   '사람',
#   '인성',
#   '좋',
#   '다',
#   '동료',
#   '상사',
#   '때문',
#   '가능',
#   '성',
#   '낮',
#   '다'],
#  ['신입', '어도', '기획', '업무', '할', '으며', '다양', '업무', '경험', '쌓', '다'],
#  ['네임',
#   '밸류',
#   '강남역',
#   '분',
#   '거리',
#   '젊',
#   '분위기',
#   '다',
#   '착함',
#   '식빵',
#   '우유',
#   '줌',
#   '월급',
#   '아침',
#   '일찍',
#   '쏨'],
#  ['호칭',
#   '수평',
#   '적',
#   '라',
#   '의견',
#   '나누',
#   '거나',
#   '아이디어',
#   '내',
#   '기',
#   '좋',
#   '았',
#   '다',
#   '업무',
#   '량',
#   '많',
#   '편',
#   '어도',
#   '그만큼',
#   '배울',
#   '었',
#   '다고',
#   '생각',
#   '든다'],
#  ['연차',
#   '자유',
#   '롭',
#   '게',
#   '쓸',
#   '고',
#   '개인',
#   '문화',
#   '강해서',
#   '회식',
#   '안',
#   '고',
#   '밥',
#   '먹',
#   '거',
#   '강요',
#   '안',
#   '함',
#   '전',
#   '직장',
#   '이런',
#   '거',
#   '강요',
#   '해서',
#   '싫',
#   '었',
#   '는데',
#   '개꿀',
#   '내',
#   '업무',
#   '끝',
#   '면',
#   '갈',
#   '고',
#   '휴양소',
#   '이용',
#   '가능',
#   '어학원',
#   '무료',
#   '수강',
#   '좋',
#   '음'],
#  ['내',
#   '던',
#   '팀',
#   '눈치',
#   '없이',
#   '퇴근',
#   '할',
#   '었',
#   '음',
#   '건',
#   '캐',
#   '다',
#   '캐',
#   '팀워크',
#   '다',
#   '부족',
#   '게',
#   '눈',
#   '보임',
#   '다',
#   '퇴근',
#   '기',
#   '바쁨'],
#  ['강남', '위치', '빵집', '카페', '제휴', '온라인', '오프라인', '강의', '초고속', '승진', '젊음'],
#  ['특출나', '면', '승진', '빠름', '젊', '분위기', '평범', '함', '그럭저럭'],
#  ['음',
#   '굳이',
#   '따지',
#   '면',
#   '팀',
#   '직원',
#   '사이',
#   '좋',
#   '았',
#   '으면',
#   '알',
#   '고',
#   '니',
#   '착한',
#   '호구',
#   '만',
#   '다닐',
#   '곳',
#   '라',
#   '성격',
#   '좋',
#   '사람',
#   '만',
#   '남',
#   '던'],
#  ['팀원',
#   '좋',
#   '았',
#   '으나',
#   '이것',
#   '만나',
#   '함',
#   '월급',
#   '밀린',
#   '적',
#   '었',
#   '고',
#   '강남',
#   '라는',
#   '회사',
#   '위치'],
#  ['실무', '투입', '유의미', '할', '고', '해', '커스', '교육', '프로그램', '다'],
#  ['사원',
#   '다',
#   '비슷',
#   '연령',
#   '대',
#   '대중',
#   '후반',
#   '강남',
#   '위치',
#   '고',
#   '으면',
#   '좋',
#   '기억',
#   '별로',
#   '음'],
#  ['장점', '는지', '도무지', '찾', '기', '강남', '다는', '장점', '음'],
#  ['새로운',
#   '업무',
#   '본인',
#   '고자',
#   '열망',
#   '으면',
#   '쉽',
#   '게',
#   '진행',
#   '해',
#   '볼',
#   '도록',
#   '권장',
#   '회사',
#   '기',
#   '때문',
#   '회사',
#   '성장',
#   '면서',
#   '본인',
#   '성장',
#   '할',
#   '음'],
#  ['영어', '관련', '계속', '나가', '실', '거', '면', '업계', '최대', '기업', '니', '경력', '쌓'],
#  ['젊',
#   '직원',
#   '많',
#   '자유',
#   '로운',
#   '분위기',
#   '복장',
#   '자유',
#   '야근',
#   '시',
#   '유연',
#   '출근',
#   '성장',
#   '기',
#   '좋',
#   '기업',
#   '정규직',
#   '근무',
#   '사람',
#   '많',
#   '음',
#   '육아',
#   '휴직',
#   '후',
#   '복직',
#   '가능'],
#  ['수평',
#   '호칭',
#   '자유',
#   '로운',
#   '의견',
#   '낼',
#   '고',
#   '업무',
#   '대한',
#   '자세',
#   '피드백',
#   '실력',
#   '향상',
#   '직접',
#   '적',
#   '느낄',
#   '다',
#   '휴양소',
#   '복지',
#   '진짜',
#   '좋',
#   '음',
#   '워크숍',
#   '이나',
#   '체육',
#   '대회',
#   '규모',
#   '커서',
#   '재미있',
#   '었',
#   '음'],
#  ['상대', '적', '짧', '연차', '팀장', '급', '올라설', '구조'],
#  ['팀',
#   '세분',
#   '화',
#   '다양',
#   '역할',
#   '겪',
#   '볼',
#   '음',
#   '다양',
#   '인력',
#   '퇴사',
#   '해서',
#   '시스템',
#   '화',
#   '음',
#   '다양',
#   '마케팅',
#   '유형',
#   '처음',
#   '배우',
#   '긴',
#   '좋',
#   '음'],
#  ['실',
#   '무진',
#   '젊',
#   '편',
#   '라',
#   '자유',
#   '로운',
#   '의사소통',
#   '가능',
#   '편',
#   '만',
#   '고',
#   '싶',
#   '으면',
#   '좋',
#   '회사'],
#  ['자기',
#   '맡',
#   '분야',
#   '업무',
#   '열심',
#   '면',
#   '능력',
#   '인정받',
#   '다',
#   '상사',
#   '눈치',
#   '고',
#   '할',
#   '다',
#   '직장',
#   '동료',
#   '간',
#   '사이',
#   '좋',
#   '다'],
#  ['연차',
#   '쓰',
#   '는데',
#   '터치',
#   '음',
#   '야근',
#   '이나',
#   '주말',
#   '면',
#   '중',
#   '유급',
#   '휴일',
#   '줌',
#   '직책',
#   '직급',
#   '없이',
#   '수평',
#   '적',
#   '인',
#   '형태',
#   '지향',
#   '상호',
#   '존대',
#   '함'],
#  ['돈',
#   '많',
#   '다',
#   '연차',
#   '별로',
#   '승진',
#   '거나',
#   '인정받',
#   '시스템',
#   '라서',
#   '성장',
#   '가능',
#   '성',
#   '많',
#   '다'],
#  ['의사',
#   '결정',
#   '상당',
#   '빠름',
#   '오전',
#   '결정',
#   '사항',
#   '저녁',
#   '실행',
#   '기',
#   '함',
#   '컨',
#   '펌',
#   '절차',
#   '심플',
#   '고',
#   '고',
#   '체제',
#   '비',
#   '효율',
#   '음',
#   '평사원',
#   '주어지',
#   '권한',
#   '상대',
#   '적',
#   '크',
#   '며',
#   '그만큼',
#   '발언',
#   '권',
#   '자유',
#   '롭',
#   '게',
#   '의견',
#   '개진',
#   '문화',
#   '형성',
#   '음',
#   '승진',
#   '자연',
#   '스럽',
#   '게',
#   '빠름'],
#  ['연차',
#   '사용',
#   '자유',
#   '로움',
#   '팀',
#   '마다',
#   '다를',
#   '음',
#   '옷차림',
#   '자유',
#   '로움',
#   '나이',
#   '또래',
#   '비슷',
#   '함'],
#  ['수평',
#   '적',
#   '인',
#   '사무실',
#   '분위기',
#   '신입',
#   '사원',
#   '눈치',
#   '고',
#   '자유',
#   '롭',
#   '게',
#   '아이디어',
#   '제안',
#   '함',
#   '체계',
#   '적',
#   '인',
#   '교육',
#   '시스템',
#   '통해',
#   '업무',
#   '역량',
#   '빠르',
#   '게',
#   '끌어올릴',
#   '음',
#   '야근',
#   '시',
#   '택시',
#   '비',
#   '지원',
#   '늦',
#   '게',
#   '출근',
#   '할',
#   '탄력',
#   '근무',
#   '음'],
#  ['마케팅',
#   '업무',
#   '업무',
#   '해',
#   '볼',
#   '음',
#   '핵심',
#   '부서',
#   '경우',
#   '가끔',
#   '외부',
#   '프로모션',
#   '진행',
#   '할',
#   '음'],
#  ['종각',
#   '라는',
#   '위치',
#   '좋',
#   '다',
#   '가까이',
#   '인사동',
#   '호떡',
#   '사',
#   '먹',
#   '고',
#   '퇴근',
#   '기',
#   '좋',
#   '다'],
#  ['자유',
#   '로운',
#   '퇴근',
#   '문화',
#   '강압',
#   '적',
#   '인',
#   '회식',
#   '음',
#   '짜인',
#   '프로세스',
#   '익',
#   '음',
#   '본인',
#   '능력',
#   '만',
#   '된다면',
#   '원',
#   '모든',
#   '업무',
#   '접해',
#   '볼',
#   '음'],
#  ['분위기',
#   '수평',
#   '적',
#   '고',
#   '니',
#   '담당',
#   '업무',
#   '범위',
#   '매우',
#   '넓',
#   '음',
#   '시키',
#   '만',
#   '고',
#   '싶',
#   '사람',
#   '에겐',
#   '단점',
#   '으나',
#   '활용',
#   '면',
#   '내',
#   '고',
#   '싶',
#   '업무',
#   '위주',
#   '직무',
#   '디자인',
#   '할',
#   '음'],
#  ['구성원',
#   '젊음',
#   '그럴',
#   '밖에',
#   '게',
#   '젊',
#   '사람',
#   '알려진',
#   '업체',
#   '라',
#   '입사',
#   '지원',
#   '인원',
#   '계속',
#   '으니까'],
#  ['아이디어',
#   '자유',
#   '롭',
#   '게',
#   '이야기',
#   '할',
#   '음',
#   '강제',
#   '적',
#   '인',
#   '회식',
#   '음',
#   '사람',
#   '좋',
#   '음'],
#  ['업계',
#   '연봉',
#   '높',
#   '편',
#   '라',
#   '돈',
#   '많이',
#   '벌',
#   '고',
#   '인센티브',
#   '제공',
#   '였',
#   '어서',
#   '번',
#   '정도',
#   '인센티브',
#   '받',
#   '았',
#   '다'],
#  ['사내',
#   '서대',
#   '온라인',
#   '교육',
#   '수강',
#   '자기',
#   '개발',
#   '가능',
#   '함',
#   '대체로',
#   '수평',
#   '적',
#   '인',
#   '사내',
#   '분위기',
#   '입사',
#   '고',
#   '만',
#   '버티',
#   '면',
#   '여름휴가',
#   '복지',
#   '만끽',
#   '할',
#   '으면',
#   '새로운',
#   '의견',
#   '이나',
#   '아이디어',
#   '열려',
#   '음'],
#  ['스케줄', '근무', '팀원', '간', '배려', '어야', '평일', '쉴', '음', '주말', '출근', '시'],
#  ['교육', '계열', '기업', '학구열', '높', '사람', '많이', '만날', '음'],
#  ['금융',
#   '공무원',
#   '편입',
#   '교육',
#   '업계',
#   '전반',
#   '적',
#   '인',
#   '실무',
#   '경험',
#   '할',
#   '음',
#   '평균',
#   '연령',
#   '낮',
#   '업무',
#   '수평',
#   '적',
#   '고',
#   '빠른',
#   '의사',
#   '결정',
#   '가능',
#   '함'],
#  ['내',
#   '업무',
#   '성과',
#   '확실',
#   '고',
#   '눈치',
#   '안',
#   '고',
#   '업무',
#   '집중',
#   '할',
#   '다는',
#   '점',
#   '직원',
#   '모두',
#   '프로',
#   '라고',
#   '부르',
#   '수평',
#   '적',
#   '인',
#   '구조',
#   '고',
#   '상사',
#   '스트레스',
#   '음',
#   '성과',
#   '압박',
#   '기',
#   '하나',
#   '열심',
#   '면',
#   '중간',
#   '중간',
#   '보상',
#   '따름',
#   '성장',
#   '업무',
#   '욕심',
#   '사람',
#   '좋',
#   '환경'],
#  ['이용',
#   '가능',
#   '대명',
#   '리조트',
#   '휴양소',
#   '객실',
#   '정말',
#   '좋',
#   '음',
#   '회사',
#   '대비',
#   '꼰대',
#   '상사',
#   '음',
#   '친밀',
#   '팀원',
#   '관계',
#   '회식',
#   '강요',
#   '음',
#   '승진',
#   '빠름',
#   '강의',
#   '무료',
#   '수강',
#   '플렉',
#   '출근',
#   '가능',
#   '함',
#   '개인',
#   '법인',
#   '카드',
#   '줌'],
#  ['장점',
#   '라',
#   '면',
#   '정도',
#   '젊',
#   '사람',
#   '맡',
#   '고',
#   '다는',
#   '점',
#   '단점',
#   '라',
#   '면',
#   '그만큼',
#   '위계질서',
#   '음',
#   '단',
#   '팀',
#   '냐',
#   '성향',
#   '매우',
#   '다르'],
#  ['휴양소',
#   '정말',
#   '싸',
#   '게',
#   '이용',
#   '가능',
#   '해서',
#   '가족',
#   '여행',
#   '기',
#   '좋',
#   '고',
#   '육아',
#   '휴직',
#   '사용',
#   '눈치',
#   '안',
#   '줌',
#   '안마사',
#   '사내',
#   '상주',
#   '해',
#   '어서',
#   '어깨',
#   '아프',
#   '거나',
#   '손목',
#   '아플',
#   '안마',
#   '받',
#   '음'],
#  ['정도',
#   '자유',
#   '로운',
#   '분위기',
#   '가지',
#   '고',
#   '다고',
#   '생각',
#   '된다',
#   '편하',
#   '게',
#   '대화',
#   '면서',
#   '업무',
#   '가능',
#   '고',
#   '점심',
#   '시간',
#   '마이',
#   '웨이',
#   '가능',
#   '점',
#   '좋',
#   '았',
#   '다'],
#  ['연차',
#   '눈치',
#   '안',
#   '고',
#   '쓸',
#   '음',
#   '나름',
#   '워',
#   '라벨',
#   '좋',
#   '편',
#   '교육비',
#   '지원',
#   '해',
#   '줌'],
#  ['많', '다', '잡일', '많', '다', '여러', '가지', '많이', '할', '다'],
#  ['체계',
#   '적',
#   '인',
#   '교육',
#   '시스템',
#   '신입',
#   '라도',
#   '찬찬',
#   '배우',
#   '면서',
#   '성장',
#   '기',
#   '알맞',
#   '곳',
#   '다',
#   '기획',
#   '기획',
#   '실현',
#   '될',
#   '가능',
#   '성',
#   '높',
#   '으며',
#   '좋',
#   '아이디어',
#   '제공',
#   '시',
#   '보상',
#   '해',
#   '제도',
#   '마련',
#   '다',
#   '팀',
#   '세분',
#   '화',
#   '다양',
#   '사람',
#   '경험',
#   '해',
#   '고',
#   '싶',
#   '사람',
#   '알맞',
#   '회사',
#   '다',
#   '서로',
#   '프로',
#   '님',
#   '라고',
#   '부르',
#   '며',
#   '프로',
#   '의식',
#   '북돋',
#   '회사',
#   '다',
#   '동기',
#   '많',
#   '아서',
#   '어울릴',
#   '기회',
#   '많',
#   '다'],
#  ['여초',
#   '단점',
#   '보단',
#   '장점',
#   '더',
#   '부각',
#   '곳',
#   '고',
#   '다',
#   '면',
#   '점점',
#   '적응',
#   '돼서',
#   '괜찮'],
#  ['장점', '회사', '서울', '으면', '비슷', '생각', '가진', '분', '많', '아서', '험담', '좋', '곳'],
#  ['잦', '이직', '체계', '인수인계', '입사', '동시', '많', '업무', '진행', '해', '볼', '다'],
#  ['네임', '밸류', '적당', '경력', '쌓', '다', '잡다', '다', '해서', '잡', '지식', '늘', '간다'],
#  ['강남', '위치', '고', '으며', '직원', '복지', '혜택', '수업', '공짜', '게', '해줌'],
#  ['기업', '항상', '비치', '식빵', '잡', '플래닛', '회사', '장단점', '아주', '정확', '나와', '음'],
#  ...]

# %%
# 리스트 하나로 만들기?
edu_lst = []
for i in range(len(edu_corpus)):
    for j in range(len(edu_corpus[i])):
        edu_lst.append(edu_corpus[i][j])

# %%
edu_lst
# Out:
# ['대',
#  '어려서',
#  '분위기',
#  '좋',
#  '음',
#  '상사',
#  '젊',
#  '어서',
#  '소통',
#  '그나마',
#  '통하',
#  '편',
#  '어학원',
#  '위',
#  '자부심',
#  '느낄',
#  '음',
#  '다양',
#  '관리법',
#  '콘텐츠',
#  '제작',
#  '능력',
#  '기를',
#  '음',
#  '교육',
#  '업계',
#  '연봉',
#  '괜찮',
#  '편',
#  '해',
#  '커스',
#  '라고',
#  '면',
#  '대',
#  '다',
#  '알',
#  '고',
#  '다',
#  '욕',
#  '그리',
#  '먹',
#  '는지',
#  '모르',
#  '겠',
#  '회사',
#  '팀',
#  '빨리',
#  '려면',
#  '정시',
#  '퇴근',
#  '많이',
#  '한다',
#  '야근',
#  '날',
#  '정해져',
#  '긴',
#  '평일',
#  '휴무',
#  '대체',
#  '해',
#  '줘서',
#  '나름',
#  '합리',
#  '적',
#  '라',
#  '느낀다',
#  '마케팅',
#  '전반',
#  '적',
#  '인',
#  '배울',
#  '곳',
#  '팀',
#  '만나',
#  '면',
#  '정시',
#  '퇴근',
#  '가능',
#  '고',
#  '능력',
#  '인정받',
#  '으면서',
#  '다닐',
#  '다',
#  '역량',
#  '빠른',
#  '진급',
#  '가능',
#  '며',
#  '마케팅',
#  '업무',
#  '빠르',
#  '게',
#  '체계',
#  '적',
#  '배울',
#  '곳',
#  '회',
#  '대',
#  '규모',
#  '전',
#  '직원',
#  '기업',
#  '행사',
#  '워크숍',
#  '송년회',
#  '음',
#  '역량',
#  '승진',
#  '빠르',
#  '며',
#  '다양',
#  '기업',
#  '문화',
#  '행사',
#  '다',
#  '수평',
#  '적',
#  '인',
#  '업무',
#  '분위기',
#  '자신',
#  '아이디어',
#  '눈치',
#  '고',
#  '제안',
#  '젊',
#  '상사',
#  '수평',
#  '적',
#  '인',
#  '분위기',
#  '상명하복',
#  '보다',
#  '회의',
#  '중심',
#  '업무',
#  '프로세스',
#  '진행',
#  '됨',
#  '사람',
#  '한테',
#  '스트레스',
#  '받',
#  '크',
#  '게',
#  '다는',
#  '장점',
#  '다양',
#  '프로젝트',
#  '많이',
#  '할',
#  '점',
#  '동료',
#  '분',
#  '다',
#  '젊',
#  '편',
#  '라',
#  '학교',
#  '분위기',
#  '연차',
#  '사용',
#  '자유',
#  '롭',
#  '많',
#  '아서',
#  '쓸',
#  '음',
#  '글쎄',
#  '장점',
#  '보다',
#  '단점',
#  '많',
#  '음',
#  '연차',
#  '눈치',
#  '안',
#  '봄',
#  '복지',
#  '신경',
#  '쓰',
#  '려는',
#  '중',
#  '강남역',
#  '가까워',
#  '서',
#  '출퇴근',
#  '용',
#  '어요',
#  '유일',
#  '장점',
#  '자율',
#  '성',
#  '정도',
#  '어서',
#  '근무',
#  '중',
#  '나가',
#  '서',
#  '산책',
#  '고',
#  '돌아올',
#  '다는',
#  '자그마',
#  '장점',
#  '었',
#  '는데',
#  '최근',
#  '부재',
#  '관리',
#  '프로그램',
#  '생겨서',
#  '분만',
#  '마우스',
#  '안',
#  '움직이',
#  '면',
#  '자리',
#  '비움',
#  '인지',
#  '사유',
#  '써야',
#  '합니다',
#  '자율',
#  '성',
#  '빼앗겼',
#  '으니',
#  '이제',
#  '장점',
#  '정말',
#  '하나',
#  '비교',
#  '적',
#  '수평',
#  '적',
#  '인',
#  '사무실',
#  '분위기',
#  '어학원',
#  '수업',
#  '지원',
#  '야근',
#  '때문',
#  '긴',
#  '함',
#  '팀',
#  '맞',
#  '으면',
#  '돈',
#  '욕심',
#  '없이',
#  '재밌',
#  '게',
#  '다닐',
#  '음',
#  '빨리',
#  '배울',
#  '너무',
#  '많',
#  '아서',
#  '근속',
#  '기간',
#  '길',
#  '젊',
#  '직원',
#  '많',
#  '친해질',
#  '연차',
#  '눈치',
#  '없이',
#  '쓸',
#  '음',
#  '떡값',
#  '음',
#  '커리어',
#  '쌓',
#  '기',
#  '좋',
#  '음',
#  '좋',
#  '회사',
#  '위치',
#  '스토리',
#  '기',
#  '편하',
#  '고',
#  '사람',
#  '젊',
#  '축',
#  '속해',
#  '좋',
#  '사람',
#  '많',
#  '강남역',
#  '역세',
#  '권',
#  '근처',
#  '회사',
#  '입니다',
#  '근속',
#  '연수',
#  '짧',
#  '아서',
#  '싫',
#  '사람',
#  '금방',
#  '안',
#  '볼',
#  '어요',
#  '나름',
#  '회사',
#  '타이틀',
#  '달',
#  '고',
#  '업무',
#  '기초',
#  '경력',
#  '쌓',
#  '기',
#  '좋',
#  '음',
#  '특',
#  '참고서',
#  '관련',
#  '된',
#  '부서',
#  '라면',
#  '꽤',
#  '프로페셔널',
#  '을까',
#  '생각',
#  '됨',
#  '영상',
#  '식',
#  '경우',
#  '부서',
#  '내',
#  '소속',
#  '영상팀',
#  '소속',
#  '구별',
#  '데',
#  '미',
#  '경력',
#  '쌓',
#  '고',
#  '싶',
#  '다면',
#  '영상팀',
#  '쪽',
#  '더',
#  '좋',
#  '다고',
#  '생각',
#  '함',
#  '중요',
#  '프로젝트',
#  '투입',
#  '됨',
#  '업무',
#  '책임감',
#  '기를',
#  '다',
#  '젊',
#  '사람',
#  '많',
#  '아서',
#  '분위',
#  '자유',
#  '롭',
#  '고',
#  '밝',
#  '다',
#  '옷',
#  '이나',
#  '머리',
#  '다',
#  '자유',
#  '롭',
#  '고',
#  '분위기',
#  '좋',
#  '았',
#  '다',
#  '팀워크',
#  '좋',
#  '보였',
#  '다',
#  '음',
#  '장점',
#  '연차',
#  '쓸',
#  '네임',
#  '밸류',
#  '인터넷',
#  '강의',
#  '수강',
#  '가능',
#  '함',
#  '휴양지',
#  '할인',
#  '금액',
#  '예약',
#  '가능',
#  '아침',
#  '먹',
#  '으라고',
#  '우유',
#  '랑',
#  '빵',
#  '줌',
#  '주변',
#  '명함',
#  '면',
#  '할인',
#  '곳',
#  '많',
#  '음',
#  '젊음',
#  '팀원',
#  '대부분',
#  '착하',
#  '다',
#  '인트라넷',
#  '다',
#  '장점',
#  '달',
#  '번',
#  '자사',
#  '강의',
#  '신청',
#  '해서',
#  '다',
#  '해',
#  '커스',
#  '라는',
#  '자부심',
#  '부케',
#  '부',
#  '인',
#  '듯',
#  '건물',
#  '넓',
#  '음',
#  '해',
#  '커스',
#  '지원',
#  '해',
#  '교육',
#  '음',
#  '강남역',
#  '라',
#  '약속',
#  '잡',
#  '기',
#  '편함',
#  '사무실',
#  '전자레인지',
#  '랑',
#  '냉장고',
#  '음',
#  '직원',
#  '대',
#  '중',
#  '후반',
#  '라',
#  '편하',
#  '고',
#  '수평',
#  '적',
#  '임',
#  '초고속',
#  '승진',
#  '가능',
#  '젊',
#  '나이',
#  '대',
#  '팀원',
#  '어서',
#  '공감대',
#  '형성',
#  '기',
#  '좋',
#  '다',
#  '이름',
#  '알아주',
#  '기업',
#  '팀',
#  '특성',
#  '상',
#  '야근',
#  '별로',
#  '음',
#  '워',
#  '라벨',
#  '가능',
#  '평소',
#  '음',
#  '강남역',
#  '앞',
#  '시',
#  '넘',
#  '게',
#  '야근',
#  '면',
#  '택시',
#  '비',
#  '지원',
#  '해',
#  '줌',
#  '퇴사',
#  '사람',
#  '많',
#  '아서',
#  '직원',
#  '교체',
#  '주기',
#  '빠르',
#  '다',
#  '니',
#  '빨리',
#  '승진',
#  '할',
#  '음',
#  '회사',
#  '리조트',
#  '쓸',
#  '음',
#  '개월',
#  '지나',
#  '면',
#  '팀',
#  '최고참',
#  '될',
#  '다는',
#  '거',
#  '여하튼',
#  '승진',
#  '빨리',
#  '할',
#  '음',
#  '교육',
#  '회사',
#  '다',
#  '니',
#  '여러',
#  '강의',
#  '다',
#  '시간',
#  '음',
#  '젊',
#  '사람',
#  '많',
#  '음',
#  '퇴사',
#  '많',
#  '아서',
#  '승진',
#  '빠름',
#  '좋아하',
#  '워커',
#  '홀릭',
#  '라면',
#  '추천',
#  '한다',
#  '야근',
#  '많이',
#  '함',
#  '함',
#  '평가',
#  '문화',
#  '다',
#  '동기',
#  '매우',
#  '끈끈',
#  '정',
#  '쌓',
#  '다',
#  '직원',
#  '젊',
#  '어서',
#  '소통',
#  '됨',
#  '사원',
#  '급',
#  '의견',
#  '제시',
#  '해도',
#  '줌',
#  '능동',
#  '적',
#  '인',
#  '업무',
#  '가능',
#  '개발자',
#  '퍼블리셔',
#  '로서',
#  '맘',
#  '편',
#  '다니',
#  '기',
#  '엔',
#  '좋',
#  '음',
#  '영어',
#  '수업',
#  '무료',
#  '음',
#  '장점',
#  '성',
#  '능력',
#  '중심',
#  '평가',
#  '기',
#  '때문',
#  '능력',
#  '출중',
#  '다면',
#  '빠른',
#  '진급',
#  '가능',
#  '다는',
#  '점',
#  '장점',
#  '직원',
#  '다',
#  '어려서',
#  '복장',
#  '자유',
#  '롭',
#  '다는',
#  '거',
#  '정도',
#  '인',
#  '아요',
#  '음',
#  '굳이',
#  '해',
#  '자면',
#  '식빵',
#  '냉장고',
#  '다',
#  '화장실',
#  '깨끗',
#  '다',
#  '점심',
#  '시간',
#  '칼',
#  '다',
#  '위치',
#  '강남',
#  '다',
#  '주변',
#  '먹',
#  '게',
#  '많',
#  '다',
#  '직원',
#  '나이',
#  '대',
#  '젊',
#  '다',
#  '정도',
#  '많',
#  '해',
#  '볼',
#  '다는',
#  '장점',
#  '비슷',
#  '또래',
#  '많',
#  '직장',
#  '동료',
#  '관계',
#  '좋',
#  '음',
#  '연차',
#  '자유',
#  '롭',
#  '게',
#  '쓸',
#  '음',
#  '네임',
#  '밸류',
#  '편리',
#  '위치',
#  '젊',
#  '연령',
#  '대',
#  '많',
#  '아서',
#  '연차',
#  '비해',
#  '경험',
#  '할',
#  '많',
#  '았',
#  '음',
#  '강남',
#  '으면',
#  '신기',
#  '게',
#  '동료',
#  '다',
#  '좋',
#  '음',
#  '사회',
#  '초년생',
#  '많이',
#  '입사',
#  '해서',
#  '연령',
#  '대',
#  '젊',
#  '고',
#  '야근',
#  '많',
#  '아서',
#  '야근',
#  '식대',
#  '지급',
#  '대',
#  '젊',
#  '들어도',
#  '으쌰',
#  '으쌰',
#  '며',
#  '게',
#  '고',
#  '빡세',
#  '게',
#  '만큼',
#  '얻',
#  '많',
#  '음',
#  '연차',
#  '눈치',
#  '안',
#  '고',
#  '사용',
#  '가능',
#  '개인',
#  '업무',
#  '주도',
#  '적',
#  '이끌',
#  '나갈',
#  '음',
#  '많',
#  '커리어',
#  '욕심',
#  '사람',
#  '좋',
#  '음',
#  '많',
#  '커리어',
#  '욕심',
#  '사람',
#  '좋',
#  '음',
#  '연령',
#  '대가',
#  '비교',
#  '적',
#  '젊',
#  '어서',
#  '팀원',
#  '끼리',
#  '의사소통',
#  '음',
#  '업무',
#  '체계',
#  '명확',
#  '해서',
#  '빠른',
#  '업무',
#  '처리',
#  '가능',
#  '함',
#  '온라인',
#  '마케팅',
#  '배울',
#  '음',
#  '다양',
#  '사이트',
#  '운영',
#  '경험',
#  '할',
#  '음',
#  '신입',
#  '들어가',
#  '서',
#  '배우',
#  '면',
#  '회사',
#  '던',
#  '적',
#  '응',
#  '함',
#  '매뉴얼',
#  '체계',
#  '확실',
#  '해서',
#  '바닥',
#  '배울',
#  '음',
#  '외',
#  '음',
#  '연차',
#  '자유',
#  '롭',
#  '게',
#  '사용',
#  '할',
#  '음',
#  '회사',
#  '인근',
#  '인프라',
#  '많',
#  '아서',
#  '이용',
#  '용',
#  '고',
#  '나름',
#  '복지',
#  '제도',
#  '개설',
#  '다',
#  '장점',
#  '많',
#  '사람',
#  '리뷰',
#  '적혀',
#  '토스트',
#  '가장',
#  '큰',
#  '장점',
#  '아닌가',
#  '싶',
#  '다',
#  '정리',
#  '안',
#  '된',
#  '토스',
#  '트기',
#  '근처',
#  '너저분',
#  '게',
#  '빵',
#  '가루',
#  '다',
#  '정말',
#  '많이',
#  '할',
#  '다',
#  '자신',
#  '멀티태스킹',
#  '능력',
#  '확인',
#  '할',
#  '젊',
#  '사람',
#  '많',
#  '기업',
#  '어서',
#  '뜻',
#  '만',
#  '맞',
#  '으면',
#  '업무',
#  '수평',
#  '적',
#  '업무',
#  '할',
#  '다',
#  '직원',
#  '젊',
#  '어서',
#  '소위',
#  '꼰대',
#  '아재',
#  '다',
#  '회식',
#  '자주',
#  '어서',
#  '회식',
#  '땜',
#  '고',
#  '그런',
#  '면',
#  '음',
#  '진급',
#  '빨리',
#  '다',
#  '실제로',
#  '대가',
#  '았',
#  '는데',
#  '팀장',
#  '자리',
#  '사람',
#  '적',
#  '게',
#  '보인',
#  '걸로',
#  '기억',
#  '한다',
#  '단점',
#  '될',
#  '다',
#  '생각',
#  '노련',
#  '함',
#  '팀장',
#  '이미지',
#  '아닌',
#  '팀장',
#  '다',
#  '특정',
#  '인',
#  '강',
#  '음',
#  '주말',
#  '평일',
#  '경계',
#  '질',
#  '음',
#  '대',
#  '어림',
#  '유연',
#  '조직',
#  '문화',
#  '여름휴가',
#  '제공',
#  '휴양소',
#  '전용',
#  '객실',
#  '제공',
#  '진급',
#  '빠르',
#  '다',
#  '강남역',
#  '이랑',
#  '가까움',
#  '잡',
#  '플래닛',
#  '평점',
#  '믿',
#  '고',
#  '직접',
#  '겪',
#  '자는',
#  '생각',
#  '부질없',
#  '음',
#  '깨달',
#  '줌',
#  '주도',
#  '적',
#  '마케팅',
#  '기획',
#  '수립',
#  '가능',
#  '규모',
#  '회사',
#  '라',
#  '엄무',
#  '분업',
#  '음',
#  '마케팅',
#  '진행시',
#  '필수',
#  '인',
#  '커뮤니티',
#  '관리',
#  '음',
#  '옷',
#  '맘대로',
#  '입',
#  '어도',
#  '됨',
#  '슬리퍼',
#  '신고',
#  '출근',
#  '함',
#  '또래',
#  '많',
#  '아서',
#  '욕',
#  '기',
#  '좋',
#  '음',
#  '팀',
#  '만나',
#  '면',
#  '괜찮',
#  '음',
#  '단',
#  '팀원',
#  ...]

# %%
# 빈도수 계산
count = Counter(edu_lst)
count
# Out:
# Counter({'대': 650,
#          '어려서': 13,
#          '분위기': 1733,
#          '좋': 4946,
#          '음': 9281,
#          '상사': 333,
#          '젊': 797,
#          '어서': 883,
#          '소통': 250,
#          '그나마': 127,
#          '통하': 29,
#          '편': 1357,
#          '어학원': 50,
#          '위': 501,
#          '자부심': 204,
#          '느낄': 181,
#          '다양': 603,
#          '관리법': 2,
#          '콘텐츠': 92,
#          '제작': 25,
#          '능력': 569,
#          '기를': 25,
#          '교육': 2270,
#          '업계': 820,
#          '연봉': 1829,
#          '괜찮': 331,
#          '해': 2476,
#          '커스': 178,
#          '라고': 683,
#          '면': 3443,
#          '다': 8044,
#          '알': 718,
#          '고': 10611,
#          '욕': 91,
#          '그리': 37,
#          '먹': 438,
#          '는지': 435,
#          '모르': 488,
#          '겠': 2281,
#          '회사': 3257,
#          '팀': 978,
#          '빨리': 161,
#          '려면': 114,
#          '정시': 87,
#          '퇴근': 808,
#          '많이': 1337,
#          '한다': 690,
#          '야근': 1852,
#          '날': 261,
#          '정해져': 64,
#          '긴': 262,
#          '평일': 71,
#          '휴무': 85,
#          '대체': 159,
#          '줘서': 35,
#          '나름': 293,
#          '합리': 224,
#          '적': 5747,
#          '라': 1203,
#          '느낀다': 7,
#          '마케팅': 317,
#          '전반': 148,
#          '인': 3002,
#          '배울': 458,
#          '곳': 673,
#          '만나': 143,
#          '가능': 999,
#          '인정받': 118,
#          '으면서': 48,
#          '다닐': 226,
#          '역량': 255,
#          '빠른': 190,
#          '진급': 80,
#          '며': 817,
#          '업무': 4593,
#          '빠르': 252,
#          '게': 4150,
#          '체계': 1192,
#          '회': 75,
#          '규모': 202,
#          '전': 267,
#          '직원': 4145,
#          '기업': 1490,
#          '행사': 183,
#          '워크숍': 19,
#          '송년회': 34,
#          '승진': 621,
#          '문화': 987,
#          '수평': 412,
#          '자신': 161,
#          '아이디어': 92,
#          '눈치': 746,
#          '제안': 25,
#          '상명하복': 19,
#          '보다': 915,
#          '회의': 173,
#          '중심': 82,
#          '프로세스': 154,
#          '진행': 368,
#          '됨': 764,
#          '사람': 3017,
#          '한테': 173,
#          '스트레스': 340,
#          '받': 986,
#          '크': 308,
#          '다는': 668,
#          '장점': 727,
#          '프로젝트': 56,
#          '할': 3278,
#          '점': 761,
#          '동료': 199,
#          '분': 533,
#          '학교': 74,
#          '연차': 1113,
#          '사용': 490,
#          '자유': 825,
#          '롭': 376,
#          '많': 4913,
#          '아서': 752,
#          '쓸': 404,
#          '글쎄': 26,
#          '단점': 399,
#          '안': 2127,
#          '봄': 96,
#          '복지': 2580,
#          '신경': 501,
#          '쓰': 664,
#          '려는': 103,
#          '중': 402,
#          '강남역': 192,
#          '가까워': 24,
#          '서': 448,
#          '출퇴근': 293,
#          '용': 40,
#          '어요': 328,
#          '유일': 26,
#          '자율': 133,
#          '성': 712,
#          '정도': 585,
#          '근무': 1920,
#          '나가': 403,
#          '산책': 4,
#          '돌아올': 3,
#          '자그마': 1,
#          '었': 1247,
#          '는데': 844,
#          '최근': 94,
#          '부재': 42,
#          '관리': 610,
#          '프로그램': 96,
#          '생겨서': 5,
#          '분만': 4,
#          '마우스': 2,
#          '움직이': 24,
#          '자리': 127,
#          '비움': 2,
#          '인지': 294,
#          '사유': 38,
#          '써야': 129,
#          '합니다': 918,
#          '빼앗겼': 1,
#          '으니': 101,
#          '이제': 65,
#          '정말': 541,
#          '하나': 397,
#          '비교': 244,
#          '사무실': 315,
#          '수업': 518,
#          '지원': 486,
#          '때문': 823,
#          '함': 3353,
#          '맞': 302,
#          '으면': 2815,
#          '돈': 420,
#          '욕심': 61,
#          '없이': 331,
#          '재밌': 39,
#          '너무': 1499,
#          '근속': 185,
#          '기간': 222,
#          '길': 952,
#          '친해질': 18,
#          '떡값': 6,
#          '커리어': 89,
#          '쌓': 174,
#          '기': 3061,
#          '위치': 276,
#          '스토리': 15,
#          '편하': 160,
#          '축': 13,
#          '속해': 7,
#          '역세': 21,
#          '권': 97,
#          '근처': 71,
#          '입니다': 455,
#          '연수': 153,
#          '짧': 175,
#          '싫': 68,
#          '금방': 81,
#          '볼': 321,
#          '타이틀': 23,
#          '달': 318,
#          '기초': 13,
#          '경력': 281,
#          '특': 169,
#          '참고서': 1,
#          '관련': 170,
#          '된': 474,
#          '부서': 778,
#          '라면': 217,
#          '꽤': 119,
#          '프로페셔널': 3,
#          '을까': 111,
#          '생각': 1839,
#          '영상': 18,
#          '식': 175,
#          '경우': 699,
#          '내': 946,
#          '소속': 28,
#          '영상팀': 5,
#          '구별': 5,
#          '데': 453,
#          '미': 35,
#          '싶': 467,
#          '다면': 267,
#          '쪽': 133,
#          '더': 1576,
#          '다고': 620,
#          '중요': 291,
#          '투입': 64,
#          '책임감': 21,
#          '분위': 4,
#          '밝': 38,
#          '옷': 23,
#          '이나': 619,
#          '머리': 26,
#          '았': 717,
#          '팀워크': 20,
#          '보였': 24,
#          '네임': 170,
#          '밸류': 155,
#          '인터넷': 43,
#          '강의': 303,
#          '수강': 117,
#          '휴양지': 7,
#          '할인': 74,
#          '금액': 32,
#          '예약': 9,
#          '아침': 151,
#          '으라고': 9,
#          '우유': 68,
#          '랑': 65,
#          '빵': 67,
#          '줌': 313,
#          '주변': 122,
#          '명함': 10,
#          '젊음': 38,
#          '팀원': 169,
#          '대부분': 293,
#          '착하': 33,
#          '인트라넷': 132,
#          '번': 393,
#          '자사': 21,
#          '신청': 53,
#          '해서': 792,
#          '라는': 639,
#          '부케': 1,
#          '부': 63,
#          '듯': 1001,
#          '건물': 201,
#          '넓': 53,
#          '약속': 34,
#          '잡': 240,
#          '편함': 74,
#          '전자레인지': 7,
#          '냉장고': 18,
#          '후반': 21,
#          '임': 915,
#          '초고속': 10,
#          '나이': 179,
#          '공감대': 9,
#          '형성': 44,
#          '이름': 132,
#          '알아주': 69,
#          '특성': 147,
#          '상': 233,
#          '별로': 208,
#          '워': 123,
#          '라벨': 122,
#          '평소': 7,
#          '앞': 159,
#          '시': 1854,
#          '넘': 99,
#          '택시': 74,
#          '비': 641,
#          '퇴사': 1061,
#          '교체': 42,
#          '주기': 25,
#          '니': 756,
#          '리조트': 28,
#          '개월': 114,
#          '지나': 34,
#          '최고참': 3,
#          '될': 421,
#          '거': 967,
#          '여하튼': 2,
#          '여러': 217,
#          '시간': 2561,
#          '빠름': 50,
#          '좋아하': 48,
#          '워커': 7,
#          '홀릭': 9,
#          '추천': 134,
#          '평가': 362,
#          '동기': 104,
#          '매우': 576,
#          '끈끈': 34,
#          '정': 100,
#          '사원': 493,
#          '급': 192,
#          '의견': 202,
#          '제시': 82,
#          '해도': 338,
#          '능동': 10,
#          '개발자': 64,
#          '퍼블리셔': 1,
#          '로서': 100,
#          '맘': 39,
#          '다니': 320,
#          '엔': 183,
#          '영어': 136,
#          '무료': 169,
#          '출중': 2,
#          '복장': 178,
#          '아요': 276,
#          '굳이': 66,
#          '자면': 48,
#          '식빵': 106,
#          '화장실': 98,
#          '깨끗': 73,
#          '점심': 233,
#          '칼': 229,
#          '강남': 205,
#          '비슷': 121,
#          '또래': 58,
#          '직장': 211,
#          '관계': 191,
#          '편리': 68,
#          '연령': 186,
#          '비해': 421,
#          '경험': 344,
#          '신기': 25,
#          '사회': 72,
#          '초년생': 39,
#          '입사': 358,
#          '식대': 204,
#          '지급': 149,
#          '들어도': 18,
#          '으쌰': 34,
#          '빡세': 79,
#          '만큼': 505,
#          '얻': 66,
#          '개인': 592,
#          '주도': 119,
#          '이끌': 47,
#          '나갈': 55,
#          '대가': 25,
#          '끼리': 191,
#          '의사소통': 50,
#          '명확': 89,
#          '처리': 216,
#          '온라인': 128,
#          '사이트': 43,
#          '운영': 303,
#          '신입': 675,
#          '들어가': 83,
#          '배우': 205,
#          '던': 385,
#          '응': 18,
#          '매뉴얼': 60,
#          '확실': 150,
#          '바닥': 12,
#          '외': 373,
#          '인근': 7,
#          '인프라': 34,
#          '이용': 116,
#          '제도': 554,
#          '개설': 3,
#          '리뷰': 46,
#          '적혀': 7,
#          '토스트': 38,
#          '가장': 189,
#          '큰': 399,
#          '아닌가': 24,
#          '정리': 42,
#          '토스': 9,
#          '트기': 5,
#          '너저분': 1,
#          '가루': 1,
#          '멀티태스킹': 4,
#          '확인': 55,
#          '뜻': 38,
#          '만': 2253,
#          '소위': 12,
#          '꼰대': 286,
#          '아재': 1,
#          '회식': 263,
#          '자주': 220,
#          '땜': 12,
#          '그런': 212,
#          '실제로': 60,
#          '팀장': 573,
#          '보인': 2,
#          '걸로': 46,
#          '기억': 67,
#          '노련': 3,
#          '이미지': 131,
#          '아닌': 271,
#          '특정': 66,
#          '강': 114,
#          '주말': 749,
#          '경계': 9,
#          '질': 214,
#          '어림': 7,
#          '유연': 64,
#          '조직': 495,
#          '여름휴가': 33,
#          '제공': 362,
#          '휴양소': 24,
#          '전용': 13,
#          '객실': 2,
#          '이랑': 91,
#          '가까움': 44,
#          '플래닛': 48,
#          '평점': 19,
#          '믿': 67,
#          '직접': 116,
#          '겪': 36,
#          '자는': 17,
#          '부질없': 2,
#          '깨달': 18,
#          '기획': 267,
#          '수립': 13,
#          '엄무': 1,
#          '분업': 7,
#          '진행시': 2,
#          '필수': 116,
#          '커뮤니티': 15,
#          '맘대로': 27,
#          '입': 78,
#          '어도': 148,
#          '슬리퍼': 4,
#          '신고': 13,
#          '출근': 978,
#          '단': 103,
#          '한정': 22,
#          '밥집': 6,
#          '종류': 15,
#          '치': 122,
#          '높': 1188,
#          '테이블': 15,
#          '됐': 60,
#          '꼽': 38,
#          '썼': 57,
#          '속한': 3,
#          '그렇게': 118,
#          '진': 156,
#          '적응': 127,
#          '쉬': 226,
#          '움': 27,
#          '사바': 5,
#          '사': 153,
#          '그것': 109,
#          '빌딩': 12,
#          '맛': 56,
#          '난': 48,
#          '인사': 293,
#          '느낌': 423,
#          '분담': 54,
#          '낼': 44,
#          '로움': 83,
#          '철저': 69,
#          '해줌': 48,
#          '학원': 787,
#          '법': 83,
#          '카로': 5,
#          '저녁': 162,
#          '밤': 62,
#          '근데': 105,
#          '매일': 216,
#          '반갑': 1,
#          '란': 56,
#          '건': 414,
#          '그냥': 371,
#          '알려진': 16,
#          '이외': 74,
#          '네요': 252,
#          '능률': 19,
#          '프로': 70,
#          '낮': 626,
#          '으며': 334,
#          '퇴': 198,
#          '강도': 426,
#          '으나': 330,
#          '해고': 8,
#          '병가': 9,
#          '휴직': 90,
#          '공식': 12,
#          '강요': 261,
#          '스케줄': 189,
#          '협의': 12,
#          '주위': 21,
#          '한다는': 119,
#          '인상': 232,
#          '줄': 406,
#          '대학교': 35,
#          '여서': 39,
#          '재미있': 35,
#          '일부': 77,
#          '빼': 77,
#          '밑': 66,
#          '착함': 21,
#          '어리': 34,
#          '생활': 184,
#          '간식': 82,
#          '시간대': 16,
#          '별': 407,
#          '줬': 443,
#          '다닌다고': 21,
#          '자취': 2,
#          '미혼자': 4,
#          '한해': 2,
#          '아주': 120,
#          '공짜': 30,
#          '쨈이': 2,
#          '구비': 19,
#          '출구': 10,
#          '거리': 48,
#          '준다': 84,
#          '쓴다': 22,
#          '수당': 515,
#          '못': 619,
#          '씀': 79,
#          '래': 4,
#          '봐야': 94,
#          '한지': 34,
#          '당시': 47,
#          '비하': 33,
#          '수준': 305,
#          '았었': 15,
#          '고요': 49,
#          '윗사람': 130,
#          '개인주의': 43,
#          '연구소': 11,
#          '쉽': 173,
#          '로운': 319,
#          '환경': 571,
#          '재택': 15,
#          '찾': 161,
#          '어려운': 90,
#          '갓': 8,
#          '시키': 271,
#          '대로': 150,
#          '된다': 226,
#          '필요': 1227,
#          '강하': 48,
#          '단체': 17,
#          '는다': 183,
#          '모두': 245,
#          '낸': 12,
#          '대해': 246,
#          '반영': 76,
#          '위해': 254,
#          '조언': 5,
#          '간': 392,
#          '합심': 2,
#          '커뮤니케이션': 165,
#          '원활': 40,
#          '시스템': 670,
#          '구축': 49,
#          '인해': 148,
#          '바빠서': 22,
#          '기회': 456,
#          '워낙': 40,
#          '들어와서': 15,
#          '개인플레이': 11,
#          '그거': 34,
#          '역': 64,
#          '가깝': 37,
#          '근로': 44,
#          '조건': 41,
#          '국내': 14,
#          '사교육': 38,
#          '훌륭': 29,
#          '선생': 360,
#          '님': 587,
#          '접근성': 29,
#          '했': 760,
#          '듯이': 71,
#          '다닌다는': 6,
#          '동아리': 19,
#          '든다': 41,
#          '도서': 27,
#          '구입': 14,
#          '교통비': 47,
#          '부분': 364,
#          '탑': 23,
#          '므로': 70,
#          '버티': 178,
#          '적합': 27,
#          '계': 87,
#          '원탑': 1,
#          '답': 120,
#          '뿌듯': 29,
#          '직책': 67,
#          '이직': 114,
#          '진짜': 245,
#          '대비': 149,
#          '되게': 23,
#          '율': 374,
#          '이루어지': 83,
#          '혼자': 74,
#          '서부터': 3,
#          '바이': 50,
#          '성향': 72,
#          '아닐': 16,
#          '월급': 525,
#          '밀리': 125,
#          '실무': 129,
#          '구조': 297,
#          '대표': 183,
#          '아예': 37,
#          '뭐': 227,
#          '채우': 62,
#          '듦': 264,
#          '수명': 4,
#          '단축': 9,
#          '됩니다': 119,
#          '휴가': 305,
#          '잠': 7,
#          '니다': 10,
#          '존재': 134,
#          '이루': 39,
#          '편안': 58,
#          '미혼': 7,
#          '카페': 76,
#          '그다지': 62,
#          '도움': 173,
#          '정해진': 50,
#          '규칙': 29,
#          '월요일': 7,
#          '금요일': 16,
#          '곤': 19,
#          '아무리': 76,
#          '해봐도': 8,
#          '식도': 1,
#          '포함': 193,
#          '남': 317,
#          '참': 69,
#          '난감': 3,
#          '사업': 512,
#          '영역': 33,
#          '늘리': 42,
#          '에선': 54,
#          '유명': 72,
#          '디자인': 82,
#          '키우': 54,
#          '갖추': 69,
#          '려고': 236,
#          '가지': 321,
#          '시도': 93,
#          '이런': 217,
#          '걸': 293,
#          '보일': 18,
#          '문서': 127,
#          '작업': 160,
#          '교통': 78,
#          '우수': 48,
#          '후': 214,
#          '엄청': 212,
#          '자기': 545,
#          '노터치': 2,
#          '잡혀': 107,
#          '가끔': 126,
#          '초특급': 1,
#          '이유': 293,
#          '아무': 69,
#          '모름': 44,
#          '찾아보': 23,
#          '복판': 12,
#          '첫': 59,
#          '나쁘': 165,
#          '책': 52,
#          '학인': 2,
#          '보통': 69,
#          '이룸': 3,
#          '서울': 52,
#          '최고': 136,
#          '그룹': 52,
#          '모든': 361,
#          '대한': 834,
#          '사이': 93,
#          '유지': 117,
#          '사실': 116,
#          '견도': 1,
#          '잦': 360,
#          '착한': 33,
#          '이틀': 20,
#          '붙여서': 10,
#          '별도': 40,
#          '관리자': 246,
#          '불': 338,
#          '서면': 7,
#          '보고': 470,
#          '마치': 26,
#          '정신': 123,
#          '매달': 60,
#          '혜택': 186,
#          '인강': 40,
#          '가까운': 35,
#          '라서': 162,
#          '애정': 31,
#          '서로': 213,
#          '대충': 33,
#          '미루': 9,
#          '감정': 50,
#          '명절': 95,
#          '선물': 47,
#          '택배': 1,
#          '배송': 3,
#          '잼': 45,
#          '오래': 407,
#          '본인': 384,
#          '주어진': 25,
#          '일정': 115,
#          '소화': 14,
#          '주로': 28,
#          '대학생': 29,
#          '밀접': 2,
#          '활력': 5,
#          '지장': 10,
#          '오피스': 3,
#          '라이프': 9,
#          '생': 153,
#          '누리': 11,
#          '누림': 1,
#          '친구': 59,
#          '사귈': 4,
#          '만난': 4,
#          '가질': 69,
#          '자취생': 15,
#          '계발': 96,
#          '슈': 3,
#          '비용': 103,
#          '계열': 14,
#          '원래': 25,
#          '공부': 110,
#          '내용': 94,
#          '일치': 5,
#          '구성': 56,
#          '부담': 109,
#          '여성': 154,
#          '차별': 98,
#          '대우': 308,
#          '느꼈': 22,
#          '취진': 6,
#          '학생': 866,
#          '외부': 101,
#          '바라보': 16,
#          '브랜드': 120,
#          '단순': 210,
#          '위한': 481,
#          '타': 210,
#          '비해서': 31,
#          '간결': 2,
#          '아날로그': 1,
#          '코로나': 53,
#          '놀': 52,
#          '사이좋': 4,
#          '레': 11,
#          '정수기': 11,
#          '거든요': 6,
#          '착해요': 1,
#          '이것저것': 56,
#          '바': 156,
#          '티': 31,
#          '애': 108,
#          '시급': 137,
#          '별관': 3,
#          '상주': 7,
#          '앉': 47,
#          '다가': 167,
#          '용품': 15,
#          '문': 8,
#          '임도': 1,
#          '덕': 12,
#          '대중교통': 5,
#          '수월': 33,
#          '급여': 537,
#          '일찍': 111,
#          '들어옴': 24,
#          '휴지': 5,
#          '아래': 67,
#          '김밥': 3,
#          '집': 133,
#          '식비': 82,
#          '마다': 575,
#          '다를': 52,
#          '면서': 474,
#          '제일': 72,
#          '댐': 17,
#          '지금': 241,
#          '앎': 10,
#          '서구': 6,
#          '즐겁': 69,
#          '어학': 36,
#          '지겹': 4,
#          '도록': 308,
#          '지겨워': 1,
#          '보람차': 6,
#          '양': 66,
#          '지도': 37,
#          '여야': 11,
#          '시야': 7,
#          '수용': 26,
#          '최소': 56,
#          '쥐': 8,
#          '짜내': 6,
#          '봤': 98,
#          '뽑': 356,
#          '싸': 28,
#          '갈': 187,
#          '드': 59,
#          '아무래도': 41,
#          '업종': 37,
#          '화목': 4,
#          '맡': 121,
#          '스킬': 33,
#          '향상': 94,
#          '소리': 75,
#          '어려': 7,
#          '기보단': 5,
#          '마음': 142,
#          '아끼': 45,
#          '무조건': 118,
#          '개': 123,
#          '꼬박꼬박': 31,
#          '제때': 63,
#          '나옵니다': 12,
#          '기반': 43,
#          '안정': 263,
#          '분야': 125,
#          '오프라인': 42,
#          '파리바': 1,
#          '뜨': 8,
#          '옆': 28,
#          '맛있': 41,
#          '콘': 17,
#          '선착순': 5,
#          '누군가': 26,
#          '냐': 74,
#          '물으면': 2,
#          '반응': 14,
#          '일으키': 3,
#          '효과': 33,
#          '솔직': 46,
#          '듣': 159,
#          '느라': 62,
#          '홍보': 90,
#          '평': 18,
#          '굳': 6,
#          '인지도': 105,
#          '지난': 6,
#          '올려서': 6,
#          '통합': 12,
#          '시킨다고': 2,
#          '될지': 16,
#          '땅': 7,
#          '놨다는': 3,
#          '오너': 60,
#          '배': 42,
#          '불리': 16,
#          '일단': 89,
#          '올라가': 38,
#          '까진': 14,
#          '걸릴': 10,
#          '턴데': 1,
#          '사내': 478,
#          '장벽': 17,
#          '느껴': 36,
#          '준': 30,
#          '쌓이': 28,
#          '혼잡': 6,
#          '무제한': 8,
#          '인데': 233,
#          '요즘': 86,
#          '그러': 118,
#          '려나': 8,
#          '아랫사람': 41,
#          '뭉쳐서': 1,
#          '해짐': 34,
#          '똑같': 48,
#          '연휴': 19,
#          '무리': 59,
#          '쨈': 11,
#          '저렴': 36,
#          '가격': 18,
#          '상당': 143,
#          '멋진': 4,
#          '숙소': 4,
#          '대명': 14,
#          '업': 140,
#          '보람': 96,
#          '수강료': 19,
#          '요': 118,
#          '글쎄요': 11,
#          '설': 26,
#          '추석': 23,
#          '보내': 50,
#          '부모': 45,
#          '직무': 118,
#          '차이': 235,
#          '대체로': 71,
#          '다수': 34,
#          '편한': 42,
#          '운동복': 1,
#          '제외': 84,
#          '통해': 130,
#          '강남구': 1,
#          '핵심': 25,
#          '지역': 51,
#          '무한': 32,
#          '플렉시블': 42,
#          '조금': 513,
#          '늦': 395,
#          '지하철': 28,
#          '광고': 68,
#          '들리': 6,
#          '웬만': 36,
#          '들으면': 25,
#          '안다는': 8,
#          '실질': 80,
#          '활용': 76,
#          '쌔': 3,
#          '턴': 9,
#          '오버': 8,
#          '심해': 15,
#          '적립': 1,
#          '발전': 423,
#          '도모': 7,
#          '인사이트': 2,
#          '가이드라인': 20,
#          '원급': 1,
#          '어쩌다': 4,
#          '씩': 190,
#          '팀부': 5,
#          '심하': 135,
#          '수록': 6,
#          '준비': 161,
#          '어려우므로': 1,
#          '병행': 12,
#          '불가': 30,
#          '선택': 74,
#          '밀릴': 17,
#          '걱정': 53,
#          '없음': 25,
#          '취직': 6,
#          '쉬운': 19,
#          '랄까': 10,
#          '싑': 1,
#          '나감': 34,
#          '연령층': 18,
#          '지내': 25,
#          '상황': 112,
#          '다르': 341,
#          '최대한': 24,
#          '간단': 13,
#          '익': 26,
#          '쉬움': 28,
#          '인생': 28,
#          '만들': 390,
#          '무': 108,
#          '윗선': 62,
#          '평판': 12,
#          '용이': 25,
#          '기억나': 3,
#          '탈': 10,
#          '퇴함': 2,
#          '갖춰져': 44,
#          '심야': 3,
#          '효율': 576,
#          '갔': 37,
#          '방법': 94,
#          '알려줌': 9,
#          '본': 100,
#          '치곤': 11,
#          '네이밍': 10,
#          '유리': 23,
#          '문제': 285,
#          '절대': 173,
#          ...})

# %%
# 가장 많이 나온 단어 50개 출력
count.most_common(50)
# Out:
# [('고', 10611),
#  ('음', 9281),
#  ('다', 8044),
#  ('적', 5747),
#  ('좋', 4946),
#  ('많', 4913),
#  ('업무', 4593),
#  ('게', 4150),
#  ('직원', 4145),
#  ('면', 3443),
#  ('함', 3353),
#  ('할', 3278),
#  ('회사', 3257),
#  ('기', 3061),
#  ('사람', 3017),
#  ('인', 3002),
#  ('으면', 2815),
#  ('복지', 2580),
#  ('시간', 2561),
#  ('해', 2476),
#  ('겠', 2281),
#  ('교육', 2270),
#  ('만', 2253),
#  ('안', 2127),
#  ('근무', 1920),
#  ('시', 1854),
#  ('야근', 1852),
#  ('생각', 1839),
#  ('연봉', 1829),
#  ('분위기', 1733),
#  ('더', 1576),
#  ('너무', 1499),
#  ('기업', 1490),
#  ('편', 1357),
#  ('많이', 1337),
#  ('었', 1247),
#  ('해야', 1243),
#  ('필요', 1227),
#  ('라', 1203),
#  ('체계', 1192),
#  ('높', 1188),
#  ('연차', 1113),
#  ('퇴사', 1061),
#  ('듯', 1001),
#  ('가능', 999),
#  ('문화', 987),
#  ('받', 986),
#  ('팀', 978),
#  ('출근', 978),
#  ('거', 967)]

# %%
# 코퍼스 생성
edu_corpus2 = []

for i in range(edu_df.shape[0]):
    edu_corpus2.append(edu_df['장점토큰화'][i])

# %%
# 리스트 하나로 만들기?
edu_lst2 = []
for i in range(len(edu_corpus2)):
    for j in range(len(edu_corpus2[i])):
        edu_lst2.append(edu_corpus2[i][j])

# %%
count = Counter(edu_lst2)
count.most_common(50)
# Out:
# [('음', 3964),
#  ('고', 3383),
#  ('다', 3165),
#  ('좋', 2130),
#  ('적', 2006),
#  ('많', 1369),
#  ('게', 1323),
#  ('할', 1274),
#  ('회사', 1204),
#  ('교육', 1147),
#  ('업무', 1132),
#  ('면', 1099),
#  ('분위기', 1083),
#  ('인', 989),
#  ('기', 989),
#  ('사람', 956),
#  ('복지', 837),
#  ('직원', 836),
#  ('편', 813),
#  ('함', 803),
#  ('가능', 731),
#  ('만', 692),
#  ('자유', 684),
#  ('기업', 667),
#  ('해', 649),
#  ('시간', 612),
#  ('근무', 606),
#  ('장점', 604),
#  ('연차', 575),
#  ('업계', 566),
#  ('젊', 531),
#  ('안', 527),
#  ('어서', 469),
#  ('높', 452),
#  ('라', 450),
#  ('다양', 428),
#  ('많이', 420),
#  ('대', 404),
#  ('눈치', 396),
#  ('승진', 390),
#  ('연봉', 387),
#  ('배울', 371),
#  ('문화', 366),
#  ('시', 356),
#  ('점', 349),
#  ('기회', 349),
#  ('수평', 341),
#  ('야근', 335),
#  ('받', 334),
#  ('체계', 333)]

# %%
# 코퍼스 생성
edu_corpus3 = []

for i in range(edu_df.shape[0]):
    edu_corpus3.append(edu_df['단점토큰화'][i])

# %%
# 리스트 하나로 만들기?
edu_lst3 = []
for i in range(len(edu_corpus3)):
    for j in range(len(edu_corpus3[i])):
        edu_lst3.append(edu_corpus3[i][j])

# %%
count = Counter(edu_lst3)
count.most_common(50)
# Out:
# [('고', 4410),
#  ('음', 4318),
#  ('다', 3553),
#  ('많', 2966),
#  ('업무', 2695),
#  ('적', 2283),
#  ('함', 1844),
#  ('게', 1671),
#  ('시간', 1607),
#  ('기', 1467),
#  ('야근', 1338),
#  ('면', 1333),
#  ('사람', 1190),
#  ('안', 1165),
#  ('회사', 1143),
#  ('인', 1106),
#  ('연봉', 1103),
#  ('직원', 1094),
#  ('근무', 1007),
#  ('너무', 971),
#  ('할', 959),
#  ('해야', 915),
#  ('만', 875),
#  ('시', 722),
#  ('복지', 699),
#  ('교육', 637),
#  ('주말', 611),
#  ('출근', 610),
#  ('생각', 560),
#  ('좋', 555),
#  ('퇴근', 554),
#  ('많이', 552),
#  ('팀', 543),
#  ('퇴사', 538),
#  ('높', 530),
#  ('받', 518),
#  ('분위기', 518),
#  ('임', 497),
#  ('경우', 494),
#  ('편', 492),
#  ('라', 480),
#  ('내', 476),
#  ('는데', 473),
#  ('연차', 460),
#  ('보다', 457),
#  ('체계', 454),
#  ('기업', 450),
#  ('못', 445),
#  ('부서', 444),
#  ('됨', 443)]
